# %%
# !pip install fiftyone

# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
name = 'CDLA_dataset'
dataset_dir = '/home/lstm/fiftyone/_CDLA_DATASET/coco'

dataset_type = fo.types.COCODetectionDataset

# %%
dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=dataset_type
    # name=name,
)
# Out:
#  100% |███████████████| 1000/1000 [44.2s elapsed, 0s remaining, 22.1 samples/s]

# %%
print(dataset)
# Out:
# Name:        2024.04.28.18.53.54
# Media type:  image
# Num samples: 1000
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:            fiftyone.core.fields.ObjectIdField
#     filepath:      fiftyone.core.fields.StringField
#     tags:          fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     detections:    fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     segmentations: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %%
sample = dataset.first()
print(sample)
# Out:
# <Sample: {
#     'id': '662e1cb24832e1ff70de2153',
#     'media_type': 'image',
#     'filepath': '/home/lstm/fiftyone/_CDLA_DATASET/coco/data/val_0828.jpg',
#     'tags': [],
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1240,
#         'height': 1754,
#         'num_channels': None,
#     }>,
#     'detections': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2143',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Header',
#                 'bounding_box': [
#                     0.4241935483870968,
#                     0.052451539338654506,
#                     0.19435483870967743,
#                     0.012542759407069556,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2144',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure',
#                 'bounding_box': [
#                     0.15,
#                     0.07924743443557583,
#                     0.7419354838709677,
#                     0.3169897377423033,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2145',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure caption',
#                 'bounding_box': [
#                     0.3540322580645161,
#                     0.40364880273660203,
#                     0.3362903225806452,
#                     0.011972633979475485,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2146',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure',
#                 'bounding_box': [
#                     0.15403225806451612,
#                     0.4224629418472064,
#                     0.7411290322580645,
#                     0.314709236031927,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2147',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure caption',
#                 'bounding_box': [
#                     0.38467741935483873,
#                     0.7445838084378563,
#                     0.27419354838709675,
#                     0.011972633979475485,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2148',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Title',
#                 'bounding_box': [
#                     0.13790322580645162,
#                     0.7708095781071835,
#                     0.14838709677419354,
#                     0.01596351197263398,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2149',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Text',
#                 'bounding_box': [
#                     0.13951612903225807,
#                     0.806157354618016,
#                     0.7645161290322581,
#                     0.09692132269099202,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214a',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Footer',
#                 'bounding_box': [
#                     0.5129032258064516,
#                     0.927023945267959,
#                     0.016935483870967744,
#                     0.00798175598631699,
#                 ],
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#         ],
#     }>,
#     'segmentations': <Detections: {
#         'detections': [
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214b',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Header',
#                 'bounding_box': [
#                     0.4241935483870968,
#                     0.052451539338654506,
#                     0.19435483870967743,
#                     0.012542759407069556,
#                 ],
#                 'mask': array([[ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214c',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure',
#                 'bounding_box': [
#                     0.15,
#                     0.07924743443557583,
#                     0.7419354838709677,
#                     0.3169897377423033,
#                 ],
#                 'mask': array([[ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214d',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure caption',
#                 'bounding_box': [
#                     0.3540322580645161,
#                     0.40364880273660203,
#                     0.3362903225806452,
#                     0.011972633979475485,
#                 ],
#                 'mask': array([[ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214e',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure',
#                 'bounding_box': [
#                     0.15403225806451612,
#                     0.4224629418472064,
#                     0.7411290322580645,
#                     0.314709236031927,
#                 ],
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de214f',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Figure caption',
#                 'bounding_box': [
#                     0.38467741935483873,
#                     0.7445838084378563,
#                     0.27419354838709675,
#                     0.011972633979475485,
#                 ],
#                 'mask': array([[ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2150',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Title',
#                 'bounding_box': [
#                     0.13790322580645162,
#                     0.7708095781071835,
#                     0.14838709677419354,
#                     0.01596351197263398,
#                 ],
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        ...,
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False],
#                        [ True,  True,  True, ...,  True,  True, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2151',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Text',
#                 'bounding_box': [
#                     0.13951612903225807,
#                     0.806157354618016,
#                     0.7645161290322581,
#                     0.09692132269099202,
#                 ],
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ...,  True,  True, False],
#                        [False, False, False, ...,  True,  True, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '662e1cb24832e1ff70de2152',
#                 'attributes': {},
#                 'tags': [],
#                 'label': 'Footer',
#                 'bounding_box': [
#                     0.5129032258064516,
#                     0.927023945267959,
#                     0.016935483870967744,
#                     0.00798175598631699,
#                 ],
#                 'mask': array([[False, False, False, False, False, False, False, False, False,
#                         False, False, False, False, False, False, False, False, False,
#                         False, False, False],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True],
#                        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True,  True,  True,  True,  True,  True,  True,
#                          True,  True,  True]]),
#                 'confidence': None,
#                 'index': None,
#                 'iscrowd': 0,
#             }>,
#         ],
#     }>,
# }>

# %%
# Open the dataset in the App
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=90205350-785b-4c76-9a85-07387c141da9"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
