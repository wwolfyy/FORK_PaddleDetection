# %% [markdown]
# # Convert PDF files to jpg format
# #### (PP has problems with png format)
# #### then save in folder named after the pdf file name
# #### also mark if the pdf file is scanned image or adobe format

# %% [markdown]
# ## 1. Define utility functions

# %%
# utility functions
import fitz
import os
import pikepdf
# import loguru
from pathlib import Path

def check_pdf_lock(doc):
    """ check if a pdf document is locked

    Args:
        doc (_fitz.Document_): pymupdf doc object

    ref: (0: allowed, 1: not allowed)

        0b00000001 (1): Print permission
        0b00000010 (2): Modify permission
        0b00000100 (4): Copy permission
        0b00001000 (8): Annotate permission
        0b00010000 (16): Form filling permission
        0b00100000 (32): Accessibility permission
        0b01000000 (64): Document assembly permission
        0b10000000 (128): Print high-quality permission
    """

    # Check if the document is encrypted (password-protected)
    if doc.is_encrypted:
        print("The PDF document is encrypted (password-protected).")
        locked = True

    # Check the document's permissions
    permissions = doc.permissions # int. See https://pymupdf.readthedocs.io/en/latest/document.html#Document.permissions

    # convert to binary
    permissions_bin = bin(permissions)[2:].zfill(8)

    print_permission = bool(permissions & 1)
    modify_permission = bool(permissions & 2)
    copy_permission = bool(permissions & 4)
    annotate_permission = bool(permissions & 8)
    form_fill_permission = bool(permissions & 16)
    accessibility_permission = bool(permissions & 32)
    assemble_permission = bool(permissions & 64)
    print_hq_permission = bool(permissions & 128)

    # Print the individual permissions
    print("Print Permission:", print_permission)
    print("Modify Permission:", modify_permission)
    print("Copy Permission:", copy_permission)
    print("Annotate Permission:", annotate_permission)
    print("Form Fill Permission:", form_fill_permission)
    print("Accessibility Permission:", accessibility_permission)
    print("Document Assembly Permission:", assemble_permission)
    print("Print High-Quality Permission:", print_hq_permission)

    return permissions, permissions_bin


def unlock_pdf(pdf_path, out_path):
    """unlock pdf modification permissions

    Args:
        doc (_fitz.Document_): pymupdf doc object
    """

    # Open the PDF file with PyMuPDF
    doc = fitz.open(pdf_path)

    # Define the permission flags
    NO_PERMISSION = 0
    PRINT_PERMISSION = 1
    MODIFY_PERMISSION = 2
    COPY_PERMISSION = 4
    ANNOTATE_PERMISSION = 8
    FORM_FILL_PERMISSION = 16
    ACCESSIBILITY_PERMISSION = 32
    ASSEMBLE_PERMISSION = 64
    PRINT_HQ_PERMISSION = 128

    # Set the desired permissions
    permissions = PRINT_PERMISSION | MODIFY_PERMISSION | COPY_PERMISSION | ANNOTATE_PERMISSION| ASSEMBLE_PERMISSION

    # Save the modified PDF with the new permissions
    doc.save(
        out_path, #incremental=True,
        encryption=fitz.PDF_ENCRYPT_KEEP,
        permissions=permissions)

    # Close the document
    doc.close()


def convert_pdf_to_images(
        pdf_folder:str = '',
        output_folder:str = "",
        scan_threshold:int = 100,
        format = 'jpg'
        ) -> None:
    """converts all pdfs in a folder to images and saves them in individual folders

    Args:
        pdf_folder (str): where PDFs located
        output_folder (str): where to save imaes (can be subfolder or pdf_folder)
        scan_threshold (int): length of text to determine if page is scanned image
    """

    doclist = os.listdir(pdf_folder)

    for pdf_path in doclist:

        try:
            if not pdf_path.endswith('.pdf'):
                continue

            pdf_name = os.path.splitext(pdf_path)[0]
            # output_folder = os.path.join(pdf_folder, pdf_name)
            # if not os.path.isdir(output_folder):
            #     os.mkdir(output_folder)

            open_path = os.path.join(pdf_folder, pdf_path)
            doc = fitz.open(open_path)

            # if check_pdf_lock(doc):
            #     print(f"----------------------- PDF {pdf_name} is locked, skipping-----------------")
            #     continue

            for page_num in range(len(doc)):
                page = doc.load_page(page_num)

                # check for scanned image wrapped in PDF foramt by extracting texts
                # extract all texts from page
                text = page.get_text()
                doctype = 'scan' if len(text) < scan_threshold else 'adobe'

                # save_path = os.path.join(output_folder, f'{doctype}_{pdf_name}', f'{doctype}_{pdf_name}_{page_num}.png')
                save_path = os.path.join(output_folder, f'{doctype}_{pdf_name}_{page_num}.{format}')
                # if not os.path.isdir(os.path.join(output_folder, f'{doctype}_{pdf_name}')):
                #     os.mkdir(os.path.join(output_folder, f'{doctype}_{pdf_name}'))
                if not os.path.isdir(output_folder):
                    os.mkdir(output_folder)
                if not os.path.isfile(save_path):
                    page.get_pixmap(dpi=200).save(save_path)
                    print(f"{pdf_name}/{page_num} saved.")
                else:
                    print(f"------------------ {save_path} exists! ---------------------")

            doc.close()
        except Exception as e:
            print(f"ERROR on {pdf_path}: {e}")


def get_image_from_pdf(doc):

    # import display from ipython
    from IPython.display import display, Image

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        pixmap = page.get_pixmap()
        # return pixmap

        # display pixmap in Jupyter notebook
        img = Image(data=pixmap.samples, format='png')
        # img.save(os.path.join())
        display(img)

        # Get the list of images on the page
        image_list = page.get_images()

        # Iterate over each image
        for image_index, img in enumerate(image_list, start=1):
            # Get the image's bounding box
            xref = img[0]  # Xref number of the image
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]

            # Get the image's dimensions
            image_width = base_image["width"]
            image_height = base_image["height"]

            # Save the image to a file
            with open(f"image_{page_num}_{image_index}.png", "wb") as f:
                f.write(image_bytes)

            print(f"Image {image_index} saved")

# %% [markdown]
# ## 2. Unlock PDFs if locked (PASS. No effect)
# #### If already unlocked, copy to the folder where the unlocked PDFs are.

# %%
pdf_folder = './testdata/misc'  # PDFs_original
# pdf_folder = '/home/lstm/fiftyone/열람판례_PDF_20240416-20240417'
# out_folder = '/home/lstm/fiftyone/temp'
out_folder = './testdata/misc/output'
pdf_list = [file for file in os.listdir(pdf_folder) if os.path.isfile(os.path.join(pdf_folder, file))]

# check permission and unlock if locked
for idx, pdf_path in enumerate(pdf_list):

    filename = Path(pdf_path).name
    print(filename)

    # check permission
    check_pdf_lock(fitz.open(os.path.join(pdf_folder, filename)))

    unlock_pdf(
        os.path.join(pdf_folder, filename),
        os.path.join(out_folder, filename)
        )

    if idx >= 5: break
# Out:
# lawnb_01031929931.pdf
# Print Permission: False
# Modify Permission: False
# Copy Permission: True
# Annotate Permission: True
# Form Fill Permission: True
# Accessibility Permission: True
# Document Assembly Permission: True
# Print High-Quality Permission: True

# %%
check_pdf_lock(os.path.join(pdf_folder, filename))

# %% [markdown]
# ## 3. Convert PDF to JPEG (PP not fully supporting PNG)

# %% [markdown]
# ### in single folder

# %%
# pdf_folder = '/home/lstm/fiftyone/열람판례_PDF_20240416-20240417'
# output_folder = '/home/lstm/fiftyone/_img_열람판례_PDF_20240416-20240417'

# pdf_folder = './testdata/PDFs_original'
# output_folder = './testdata/CONVERTED_JPEG'

# pdf_folder = '/home/lstm/fiftyone/열람판례_PDF_20240416-20240417'
# output_folder = './testdata/CONVERTED_JPEG_batch2'

# pdf_folder = './testdata/PDFs_original/patent_cases'
# output_folder = './testdata/CONVERTED_JPEG_batch_patent'

pdf_folder = '/home/lstm/KR case dataset/열람판례 PDF_20240521-20240522'
output_folder = '/home/lstm/KR case dataset/_img_열람판례 PDF_20240521-20240522'

convert_pdf_to_images(pdf_folder, output_folder)
# Out:
# 서울중앙지법_2014나71025_판결서/0 saved.
# 서울중앙지법_2014나71025_판결서/1 saved.
# 서울중앙지법_2014나71025_판결서/2 saved.
# 서울중앙지법_2014나71025_판결서/3 saved.
# 서울중앙지법_2014나71025_판결서/4 saved.
# 서울중앙지법_2014나71025_판결서/5 saved.
# 진주지원_2014가단13675_판결서/0 saved.
# 진주지원_2014가단13675_판결서/1 saved.
# 진주지원_2014가단13675_판결서/2 saved.
# 진주지원_2014가단13675_판결서/3 saved.
# 진주지원_2014가단13675_판결서/4 saved.
# 진주지원_2014가단13675_판결서/5 saved.
# 진주지원_2014가단13675_판결서/6 saved.
# 진주지원_2014가단13675_판결서/7 saved.
# 진주지원_2014가단13675_판결서/8 saved.
# 부산고법_2014나2211_판결서/0 saved.
# 부산고법_2014나2211_판결서/1 saved.
# 부산고법_2014나2211_판결서/2 saved.
# 부산고법_2014나2211_판결서/3 saved.
# 부산고법_2014나2211_판결서/4 saved.
# 부산고법_2014나2211_판결서/5 saved.
# 부산고법_2014나2211_판결서/6 saved.
# 부산고법_2014나2211_판결서/7 saved.
# 부산고법_2014나2211_판결서/8 saved.
# 부산고법_2014나2211_판결서/9 saved.
# 부산고법_2014나2211_판결서/10 saved.
# 부산고법_2014나2211_판결서/11 saved.
# 창원지법_2014가단77003_판결서/0 saved.
# 창원지법_2014가단77003_판결서/1 saved.
# 창원지법_2014가단77003_판결서/2 saved.
# 창원지법_2014가단77003_판결서/3 saved.
# 창원지법_2014가단77003_판결서/4 saved.
# 창원지법_2014가단77003_판결서/5 saved.
# 서울중앙지법_2016가단4165_판결서/0 saved.
# 서울중앙지법_2016가단4165_판결서/1 saved.
# 서울중앙지법_2016가단4165_판결서/2 saved.
# 서울고법_2013나69998_판결서/0 saved.
# 서울고법_2013나69998_판결서/1 saved.
# 서울고법_2013나69998_판결서/2 saved.
# 서울고법_2013나69998_판결서/3 saved.
# 서울고법_2013나69998_판결서/4 saved.
# 서울고법_2013나69998_판결서/5 saved.
# 서울고법_2013나69998_판결서/6 saved.
# 서울고법_2013나69998_판결서/7 saved.
# 서울고법_2013나69998_판결서/8 saved.
# 서울고법_2013나69998_판결서/9 saved.
# 고양지원_2013가단509220_판결서/0 saved.
# 고양지원_2013가단509220_판결서/1 saved.
# 고양지원_2013가단509220_판결서/2 saved.
# 고양지원_2013가단509220_판결서/3 saved.
# 고양지원_2013가단509220_판결서/4 saved.
# 고양지원_2013가단509220_판결서/5 saved.
# 인천지법_2014나12898_판결서/0 saved.
# 인천지법_2014나12898_판결서/1 saved.
# 인천지법_2014나12898_판결서/2 saved.
# 인천지법_2014나12898_판결서/3 saved.
# 인천지법_2014나12898_판결서/4 saved.
# 대법원_2016다5788_판결서/0 saved.
# 대법원_2016다5788_판결서/1 saved.
# 대법원_2016다5788_판결서/2 saved.
# 대법원_2016다5788_판결서/3 saved.
# 서울동부지법_2015가합203_판결서/0 saved.
# 서울동부지법_2015가합203_판결서/1 saved.
# 서울동부지법_2015가합203_판결서/2 saved.
# 서울동부지법_2015가합203_판결서/3 saved.
# 서울동부지법_2015가합203_판결서/4 saved.
# 서울중앙지법_2014나2289_판결서/0 saved.
# 서울중앙지법_2014나2289_판결서/1 saved.
# 서울중앙지법_2014나2289_판결서/2 saved.
# 서울중앙지법_2014나2289_판결서/3 saved.
# 서울중앙지법_2014나2289_판결서/4 saved.
# 서울중앙지법_2014나2289_판결서/5 saved.
# 서울중앙지법_2014나2289_판결서/6 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/0 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/1 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/2 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/3 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/4 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/5 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/6 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/7 saved.
# 인천지방법원 부천지원_2014가합4162_판결서/8 saved.
# 제주지법_2014가단46401_경정결정/0 saved.
# 서울북부지법_2014가단119864_판결서/0 saved.
# 서울북부지법_2014가단119864_판결서/1 saved.
# 서울북부지법_2014가단119864_판결서/2 saved.
# 서울북부지법_2014가단119864_판결서/3 saved.
# 서울북부지법_2014가단119864_판결서/4 saved.
# 서울서부지법_2014가단255612_판결서/0 saved.
# 서울서부지법_2014가단255612_판결서/1 saved.
# 서울서부지법_2014가단255612_판결서/2 saved.
# 서울서부지법_2014가단255612_판결서/3 saved.
# 대전지법_2015구합102735_판결서/0 saved.
# 대전지법_2015구합102735_판결서/1 saved.
# 대전지법_2015구합102735_판결서/2 saved.
# 대전지법_2015구합102735_판결서/3 saved.
# 대전지법_2015구합102735_판결서/4 saved.
# 대전지법_2015구합102735_판결서/5 saved.
# 대전지법_2015구합102735_판결서/6 saved.
# 대전지법_2015구합102735_판결서/7 saved.
# 대전지법_2015구합102735_판결서/8 saved.
# 대전지법_2015구합102735_판결서/9 saved.
# 고양지원_2014가단63431_판결서/0 saved.
# 고양지원_2014가단63431_판결서/1 saved.
# 고양지원_2014가단63431_판결서/2 saved.
# 고양지원_2014가단63431_판결서/3 saved.
# 고양지원_2014가단63431_판결서/4 saved.
# 울산지법_2014가단30789_판결서/0 saved.
# 울산지법_2014가단30789_판결서/1 saved.
# 울산지법_2014가단30789_판결서/2 saved.
# 울산지법_2014가단30789_판결서/3 saved.
# 서울중앙지법_2014나49240_판결서/0 saved.
# 서울중앙지법_2014나49240_판결서/1 saved.
# 서울중앙지법_2014나49240_판결서/2 saved.
# 서울중앙지법_2014나49240_판결서/3 saved.
# 서울중앙지법_2014나49240_판결서/4 saved.
# 서울중앙지법_2014나49240_판결서/5 saved.
# 서울중앙지법_2014나49240_판결서/6 saved.
# 서울중앙지법_2014나49240_판결서/7 saved.
# 서울중앙지법_2014나49240_판결서/8 saved.
# 서울남부지법_2014가단54193_판결서/0 saved.
# 서울남부지법_2014가단54193_판결서/1 saved.
# 서울남부지법_2014가단54193_판결서/2 saved.
# 서울남부지법_2014가단54193_판결서/3 saved.
# 서울남부지법_2014가단54193_판결서/4 saved.
# 서울남부지법_2014가단54193_판결서/5 saved.
# 서울서부지법_2015가단207092_판결서/0 saved.
# 서울서부지법_2015가단207092_판결서/1 saved.
# 서울서부지법_2015가단207092_판결서/2 saved.
# 서울서부지법_2015가단207092_판결서/3 saved.
# 서울서부지법_2015가단207092_판결서/4 saved.
# 서울서부지법_2015가단207092_판결서/5 saved.
# 서울서부지법_2015가단207092_판결서/6 saved.
# 서울서부지법_2015가단207092_판결서/7 saved.
# 고양지원_2014가단5107_판결서/0 saved.
# 고양지원_2014가단5107_판결서/1 saved.
# 고양지원_2014가단5107_판결서/2 saved.
# 고양지원_2014가단5107_판결서/3 saved.
# 고양지원_2014가단5107_판결서/4 saved.
# 고양지원_2014가단5107_판결서/5 saved.
# 서울북부지법_2015나31009_판결서/0 saved.
# 서울북부지법_2015나31009_판결서/1 saved.
# 서울북부지법_2015나31009_판결서/2 saved.
# 서울북부지법_2015나31009_판결서/3 saved.
# 서울서부지법_2014가단39759_판결서/0 saved.
# 서울서부지법_2014가단39759_판결서/1 saved.
# 서울서부지법_2014가단39759_판결서/2 saved.
# 성남지원_2014가합202826_판결서/0 saved.
# 성남지원_2014가합202826_판결서/1 saved.
# 성남지원_2014가합202826_판결서/2 saved.
# 성남지원_2014가합202826_판결서/3 saved.
# 창원지법_2014가단24801_판결서/0 saved.
# 창원지법_2014가단24801_판결서/1 saved.
# 창원지법_2014가단24801_판결서/2 saved.
# 창원지법_2014가단24801_판결서/3 saved.
# 대전지법_2014나105446_판결서/0 saved.
# 대전지법_2014나105446_판결서/1 saved.
# 대전지법_2014나105446_판결서/2 saved.
# 대전지법_2014나105446_판결서/3 saved.
# 대전지법_2014나105446_판결서/4 saved.
# 대전지법_2014나105446_판결서/5 saved.
# 대전지법_2014나105446_판결서/6 saved.
# 대전지법_2014나105446_판결서/7 saved.
# 대전지법_2014나105446_판결서/8 saved.
# 서울중앙지법_2014가단250704_판결서/0 saved.
# 서울중앙지법_2014가단250704_판결서/1 saved.
# 서울중앙지법_2014가단250704_판결서/2 saved.
# 서울중앙지법_2014가단119940_판결서/0 saved.
# 서울중앙지법_2014가단119940_판결서/1 saved.
# 서울중앙지법_2014가단119940_판결서/2 saved.
# 성남지원_2014가합1207_판결서/0 saved.
# 성남지원_2014가합1207_판결서/1 saved.
# 성남지원_2014가합1207_판결서/2 saved.
# 성남지원_2014가합1207_판결서/3 saved.
# 성남지원_2014가합1207_판결서/4 saved.
# 성남지원_2014가합1207_판결서/5 saved.
# 성남지원_2014가합1207_판결서/6 saved.
# 성남지원_2014가합1207_판결서/7 saved.
# 서울동부지법_2014가합10463_판결서/0 saved.
# 서울동부지법_2014가합10463_판결서/1 saved.
# 서울동부지법_2014가합10463_판결서/2 saved.
# 서울동부지법_2014가합10463_판결서/3 saved.
# 서울동부지법_2014가합10463_판결서/4 saved.
# 서울동부지법_2014가합10463_판결서/5 saved.
# 서울동부지법_2014가합10463_판결서/6 saved.
# 서울동부지법_2014가합10463_판결서/7 saved.
# 서울동부지법_2014가합10463_판결서/8 saved.
# 성남지원_2012가합23326_별지/0 saved.
# 성남지원_2012가합23326_별지/1 saved.
# 성남지원_2012가합23326_별지/2 saved.
# 성남지원_2012가합23326_별지/3 saved.
# 성남지원_2012가합23326_별지/4 saved.
# 성남지원_2012가합23326_별지/5 saved.
# 성남지원_2012가합23326_별지/6 saved.
# 성남지원_2012가합23326_별지/7 saved.
# 성남지원_2012가합23326_별지/8 saved.
# 성남지원_2012가합23326_별지/9 saved.
# 성남지원_2012가합23326_별지/10 saved.
# 성남지원_2012가합23326_별지/11 saved.
# 성남지원_2012가합23326_별지/12 saved.
# 성남지원_2012가합23326_별지/13 saved.
# 성남지원_2012가합23326_별지/14 saved.
# 성남지원_2012가합23326_별지/15 saved.
# 성남지원_2012가합23326_별지/16 saved.
# 성남지원_2012가합23326_별지/17 saved.
# 성남지원_2012가합23326_별지/18 saved.
# 성남지원_2012가합23326_별지/19 saved.
# 성남지원_2012가합23326_별지/20 saved.
# 서울중앙지법_2014가단5322659_판결서/0 saved.
# 서울중앙지법_2014가단5322659_판결서/1 saved.
# 서울중앙지법_2014가단5322659_판결서/2 saved.
# 서울중앙지법_2014가단5322659_판결서/3 saved.
# 서울중앙지법_2014가단5343588_판결서/0 saved.
# 서울중앙지법_2014가단5343588_판결서/1 saved.
# 서울중앙지법_2014가단5343588_판결서/2 saved.
# 서울중앙지법_2014가단5343588_판결서/3 saved.
# 의정부지법_2014가단116110_판결서/0 saved.
# 의정부지법_2014가단116110_판결서/1 saved.
# 의정부지법_2014가단116110_판결서/2 saved.
# 의정부지법_2014가단116110_판결서/3 saved.
# 의정부지법_2014가단116110_판결서/4 saved.
# 의정부지법_2014가단116110_판결서/5 saved.
# 의정부지법_2014가단116110_판결서/6 saved.
# 의정부지법_2014가단116110_판결서/7 saved.
# 서울중앙지법_2014가단237312_판결서/0 saved.
# 서울중앙지법_2014가단237312_판결서/1 saved.
# 서울중앙지법_2014가단237312_판결서/2 saved.
# 서울중앙지법_2014가단237312_판결서/3 saved.
# 성남지원_2014가합201618_판결서/0 saved.
# 성남지원_2014가합201618_판결서/1 saved.
# 성남지원_2014가합201618_판결서/2 saved.
# 성남지원_2014가합201618_판결서/3 saved.
# 성남지원_2014가합201618_판결서/4 saved.
# 성남지원_2014가합201618_판결서/5 saved.
# 성남지원_2014가단224058_판결서/0 saved.
# 성남지원_2014가단224058_판결서/1 saved.
# 성남지원_2014가단224058_판결서/2 saved.
# 성남지원_2014가단224058_판결서/3 saved.
# 성남지원_2014가단224058_판결서/4 saved.
# 성남지원_2014가단224058_판결서/5 saved.
# 대법원_2013다215690_판결서/0 saved.
# 대법원_2013다215690_판결서/1 saved.
# 대법원_2013다215690_판결서/2 saved.
# 대법원_2013다215690_판결서/3 saved.
# 서울행정법원_2015구합71242_판결서/0 saved.
# 서울행정법원_2015구합71242_판결서/1 saved.
# 서울행정법원_2015구합71242_판결서/2 saved.
# 서울행정법원_2015구합71242_판결서/3 saved.
# 서울행정법원_2015구합71242_판결서/4 saved.
# 서울행정법원_2015구합71242_판결서/5 saved.
# 서울행정법원_2015구합71242_판결서/6 saved.
# 서울행정법원_2015구합71242_판결서/7 saved.
# 서울행정법원_2015구합71242_판결서/8 saved.
# 서울행정법원_2015구합71242_판결서/9 saved.
# 서울행정법원_2015구합71242_판결서/10 saved.
# 서울행정법원_2015구합71242_판결서/11 saved.
# 서울행정법원_2015구합71242_판결서/12 saved.
# 서울행정법원_2015구합71242_판결서/13 saved.
# 서울행정법원_2015구합71242_판결서/14 saved.
# 서울행정법원_2015구합71242_판결서/15 saved.
# 서울행정법원_2015구합71242_판결서/16 saved.
# 대구지법_2014가단55939_판결서/0 saved.
# 대구지법_2014가단55939_판결서/1 saved.
# 대구지법_2014가단55939_판결서/2 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/0 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/1 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/2 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/3 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/4 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/5 saved.
# 인천지방법원 부천지원_2014가단43191_판결서/6 saved.
# 인천지법_2013가합17908_판결서/0 saved.
# 인천지법_2013가합17908_판결서/1 saved.
# 인천지법_2013가합17908_판결서/2 saved.
# 인천지법_2013가합17908_판결서/3 saved.
# 인천지법_2013가합17908_판결서/4 saved.
# 인천지법_2013가합17908_판결서/5 saved.
# 인천지법_2013가합17908_판결서/6 saved.
# 인천지법_2013가합17908_판결서/7 saved.
# 인천지법_2013가합17908_판결서/8 saved.
# 인천지법_2013가합17908_판결서/9 saved.
# 인천지법_2013가합17908_판결서/10 saved.
# 인천지법_2013가합17908_판결서/11 saved.
# 원주지원_2014가단5417_판결서/0 saved.
# 원주지원_2014가단5417_판결서/1 saved.
# 원주지원_2014가단5417_판결서/2 saved.
# 부산지법_2013가합8772_판결서/0 saved.
# 부산지법_2013가합8772_판결서/1 saved.
# 부산지법_2013가합8772_판결서/2 saved.
# 부산지법_2013가합8772_판결서/3 saved.
# 부산지법_2013가합8772_판결서/4 saved.
# 부산지법_2013가합8772_판결서/5 saved.
# 부산지법_2013가합8772_판결서/6 saved.
# 부산지법_2013가합8772_판결서/7 saved.
# 부산지법_2013가합8772_판결서/8 saved.
# 부산지법_2013가합8772_판결서/9 saved.
# 부산지법_2013가합8772_판결서/10 saved.
# 부산지법_2013가합8772_판결서/11 saved.
# 부산지법_2013가합8772_판결서/12 saved.
# 대전지법_2014가단22137_판결서/0 saved.
# 대전지법_2014가단22137_판결서/1 saved.
# 대전지법_2014가단22137_판결서/2 saved.
# 대전지법_2014가단22137_판결서/3 saved.
# 대전지법_2014가단22137_판결서/4 saved.
# 대전지법_2014가단22137_판결서/5 saved.
# 서울중앙지법_2016가단5013829_판결서/0 saved.
# 서울중앙지법_2016가단5013829_판결서/1 saved.
# 서울중앙지법_2016가단5013829_판결서/2 saved.
# 인천지법_2012가단82816_판결서/0 saved.
# 인천지법_2012가단82816_판결서/1 saved.
# 인천지법_2012가단82816_판결서/2 saved.
# 인천지법_2012가단82816_판결서/3 saved.
# 부산지법_2013가단104260_판결서/0 saved.
# 부산지법_2013가단104260_판결서/1 saved.
# 부산지법_2013가단104260_판결서/2 saved.
# 부산지법_2013가단104260_판결서/3 saved.
# 부산지법_2013가단104260_판결서/4 saved.
# 부산지법_2013가단104260_판결서/5 saved.
# 부산지법_2013가단104260_판결서/6 saved.
# 서울고법_2014나2041085_판결서/0 saved.
# 서울고법_2014나2041085_판결서/1 saved.
# 서울고법_2014나2041085_판결서/2 saved.
# 서울고법_2014나2041085_판결서/3 saved.
# 서울고법_2014나2041085_판결서/4 saved.
# 서울고법_2014나2041085_판결서/5 saved.
# 서울고법_2014나2041085_판결서/6 saved.
# 서울고법_2014나2041085_판결서/7 saved.
# 서울행정법원_2015구합75664_판결서/0 saved.
# 서울행정법원_2015구합75664_판결서/1 saved.
# 서울행정법원_2015구합75664_판결서/2 saved.
# 서울행정법원_2015구합75664_판결서/3 saved.
# 서울행정법원_2015구합75664_판결서/4 saved.
# 서울행정법원_2015구합75664_판결서/5 saved.
# 서울행정법원_2015구합75664_판결서/6 saved.
# 서울행정법원_2015구합75664_판결서/7 saved.
# 서울행정법원_2015구합75664_판결서/8 saved.
# 서울행정법원_2015구합75664_판결서/9 saved.
# 서울행정법원_2015구합75664_판결서/10 saved.
# 서울행정법원_2015구합75664_판결서/11 saved.
# 서울행정법원_2015구합75664_판결서/12 saved.
# 서울행정법원_2015구합75664_판결서/13 saved.
# 서울행정법원_2015구합75664_판결서/14 saved.
# 인천지법_2014가단223918_판결서/0 saved.
# 인천지법_2014가단223918_판결서/1 saved.
# 인천지법_2014가단223918_판결서/2 saved.
# 성남지원_2014가합4428_판결서/0 saved.
# 성남지원_2014가합4428_판결서/1 saved.
# 성남지원_2014가합4428_판결서/2 saved.
# 서울남부지법_2014가단227649_판결서/0 saved.
# 서울남부지법_2014가단227649_판결서/1 saved.
# 서울남부지법_2014가단227649_판결서/2 saved.
# 서울남부지법_2014가단227649_판결서/3 saved.
# 서울남부지법_2014가단227649_판결서/4 saved.
# 서울남부지법_2014가단227649_판결서/5 saved.
# 성남지원_2014가단25817_판결서/0 saved.
# 성남지원_2014가단25817_판결서/1 saved.
# 성남지원_2014가단25817_판결서/2 saved.
# 성남지원_2014가단25817_판결서/3 saved.
# 성남지원_2014가단25817_판결서/4 saved.
# 성남지원_2014가단25817_판결서/5 saved.
# 성남지원_2014가단25817_판결서/6 saved.
# 대전지법_2014가단41671_판결서/0 saved.
# 대전지법_2014가단41671_판결서/1 saved.
# 대전지법_2014가단41671_판결서/2 saved.
# 대전지법_2014가단41671_판결서/3 saved.
# 대전지법_2014가단41671_판결서/4 saved.
# 서울중앙지법_2014가단5062735_판결서/0 saved.
# 서울중앙지법_2014가단5062735_판결서/1 saved.
# 서울중앙지법_2014가단5062735_판결서/2 saved.
# 서울중앙지법_2014가단5062735_판결서/3 saved.
# 서울중앙지법_2014가단5062735_판결서/4 saved.
# 서울중앙지법_2014가단5062735_판결서/5 saved.
# 서울중앙지법_2014가단5062735_판결서/6 saved.
# 서울중앙지법_2014가단5062735_판결서/7 saved.
# 서울중앙지법_2014가단5062735_판결서/8 saved.
# 서울중앙지법_2014가단5062735_판결서/9 saved.
# 서울남부지법_2014가단241928_판결서/0 saved.
# 서울남부지법_2014가단241928_판결서/1 saved.
# 서울남부지법_2014가단241928_판결서/2 saved.
# 울산지법_2014가단57463_판결서/0 saved.
# 울산지법_2014가단57463_판결서/1 saved.
# 울산지법_2014가단57463_판결서/2 saved.
# 울산지법_2014가단57463_판결서/3 saved.
# 울산지법_2014가단57463_판결서/4 saved.
# 안양지원_2014가단112512_판결서/0 saved.
# 안양지원_2014가단112512_판결서/1 saved.
# 안양지원_2014가단112512_판결서/2 saved.
# 안양지원_2014가단112512_판결서/3 saved.
# 안양지원_2014가단112512_판결서/4 saved.
# 안양지원_2014가단112512_판결서/5 saved.
# 안양지원_2014가단112512_판결서/6 saved.
# 안양지원_2014가단112512_판결서/7 saved.
# 안양지원_2014가단112512_판결서/8 saved.
# 안양지원_2014가단112512_판결서/9 saved.
# 안양지원_2014가단112512_판결서/10 saved.
# 안양지원_2014가단112512_판결서/11 saved.
# 안양지원_2014가단112512_판결서/12 saved.
# 안양지원_2014가단112512_판결서/13 saved.
# 안양지원_2014가단112512_판결서/14 saved.
# 부산지법동부지원_2014가단23791_판결서/0 saved.
# 부산지법동부지원_2014가단23791_판결서/1 saved.
# 부산지법동부지원_2014가단23791_판결서/2 saved.
# 부산지법동부지원_2014가단23791_판결서/3 saved.
# 부산지법동부지원_2014가단23791_판결서/4 saved.
# 부산지법동부지원_2014가단23791_판결서/5 saved.
# 부산지법동부지원_2014가단23791_판결서/6 saved.
# 부산지법동부지원_2014가단23791_판결서/7 saved.
# 대전지방법원 공주지원_2013가합20065_별지7/0 saved.
# 성남지원_2012가합23326_판결서/0 saved.
# 성남지원_2012가합23326_판결서/1 saved.
# 성남지원_2012가합23326_판결서/2 saved.
# 성남지원_2012가합23326_판결서/3 saved.
# 성남지원_2012가합23326_판결서/4 saved.
# 성남지원_2012가합23326_판결서/5 saved.
# 성남지원_2012가합23326_판결서/6 saved.
# 성남지원_2012가합23326_판결서/7 saved.
# 성남지원_2012가합23326_판결서/8 saved.
# 성남지원_2012가합23326_판결서/9 saved.
# 성남지원_2012가합23326_판결서/10 saved.
# 성남지원_2012가합23326_판결서/11 saved.
# 성남지원_2012가합23326_판결서/12 saved.
# 성남지원_2012가합23326_판결서/13 saved.
# 성남지원_2012가합23326_판결서/14 saved.
# 성남지원_2012가합23326_판결서/15 saved.
# 성남지원_2012가합23326_판결서/16 saved.
# 성남지원_2012가합23326_판결서/17 saved.
# 성남지원_2012가합23326_판결서/18 saved.
# 성남지원_2012가합23326_판결서/19 saved.
# 성남지원_2012가합23326_판결서/20 saved.
# 성남지원_2012가합23326_판결서/21 saved.
# 성남지원_2012가합23326_판결서/22 saved.
# 성남지원_2012가합23326_판결서/23 saved.
# 성남지원_2012가합23326_판결서/24 saved.
# 성남지원_2012가합23326_판결서/25 saved.
# 성남지원_2012가합23326_판결서/26 saved.
# 성남지원_2012가합23326_판결서/27 saved.
# 성남지원_2012가합23326_판결서/28 saved.
# 서울중앙지법_2015가합8471_판결서/0 saved.
# 서울중앙지법_2015가합8471_판결서/1 saved.
# 서울중앙지법_2015가합8471_판결서/2 saved.
# 서울중앙지법_2015가합8471_판결서/3 saved.
# 대전지법_2013가단25306_판결서/0 saved.
# 대전지법_2013가단25306_판결서/1 saved.
# 대전지법_2013가단25306_판결서/2 saved.
# 대전지법_2013가단25306_판결서/3 saved.
# 대전지법_2013가단25306_판결서/4 saved.
# 대전지법_2013가단25306_판결서/5 saved.
# 대전지법_2013가단25306_판결서/6 saved.
# 대전지법_2013가단25306_판결서/7 saved.
# 대전지법_2013가단25306_판결서/8 saved.
# 대전지법_2013가단25306_판결서/9 saved.
# 대전지법_2013가단25306_판결서/10 saved.
# 대구지법서부지원_2014가단27016_판결서/0 saved.
# 대구지법서부지원_2014가단27016_판결서/1 saved.
# 대구지법서부지원_2014가단27016_판결서/2 saved.
# 대구지법서부지원_2014가단27016_판결서/3 saved.
# 대구지법서부지원_2014가단27016_판결서/4 saved.
# 대구지법서부지원_2014가단27016_판결서/5 saved.
# 대전지법_2014가단31995_판결서/0 saved.
# 대전지법_2014가단31995_판결서/1 saved.
# 대전지법_2014가단31995_판결서/2 saved.
# 대전지법_2014가단31995_판결서/3 saved.
# 대전지법_2014가단31995_판결서/4 saved.
# 대전지법_2014가단31995_판결서/5 saved.
# 대전지법_2014가단31995_판결서/6 saved.
# 대전지법_2014가단31995_판결서/7 saved.
# 대전지방법원 천안지원_2014가단19116_판결서/0 saved.
# 대전지방법원 천안지원_2014가단19116_판결서/1 saved.
# 대전지방법원 천안지원_2014가단19116_판결서/2 saved.
# 대전지방법원 천안지원_2014가단19116_판결서/3 saved.
# 대전지방법원 천안지원_2014가단19116_판결서/4 saved.
# 서울북부지법_2014나4680_판결서/0 saved.
# 서울북부지법_2014나4680_판결서/1 saved.
# 서울북부지법_2014나4680_판결서/2 saved.
# 서울북부지법_2014나4680_판결서/3 saved.
# 서울북부지법_2014나4680_판결서/4 saved.
# 서울서부지법_2012가단42812_판결서/0 saved.
# 서울서부지법_2012가단42812_판결서/1 saved.
# 서울서부지법_2012가단42812_판결서/2 saved.
# 서울서부지법_2012가단42812_판결서/3 saved.
# 서울서부지법_2012가단42812_판결서/4 saved.
# 서울서부지법_2012가단42812_판결서/5 saved.
# 서울서부지법_2012가단42812_판결서/6 saved.
# 서울서부지법_2012가단42812_판결서/7 saved.
# 서울서부지법_2012가단42812_판결서/8 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/0 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/1 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/2 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/3 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/4 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/5 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/6 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/7 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/8 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/9 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/10 saved.
# 인천지방법원 부천지원_2014가합6380_판결서/11 saved.
# 대전지법_2015구합100920_판결서/0 saved.
# 대전지법_2015구합100920_판결서/1 saved.
# 대전지법_2015구합100920_판결서/2 saved.
# 대전지법_2015구합100920_판결서/3 saved.
# 대전지법_2015구합100920_판결서/4 saved.
# 대전지법_2015구합100920_판결서/5 saved.
# 대전지법_2015구합100920_판결서/6 saved.
# 대전지법_2015구합100920_판결서/7 saved.
# 대전지법_2015구합100920_판결서/8 saved.
# 대전지법_2015구합100920_판결서/9 saved.
# 대전지법_2015구합100920_판결서/10 saved.
# 대전지법_2015구합100920_판결서/11 saved.
# 대전지법_2015구합100920_판결서/12 saved.
# 광주지방법원 순천지원_2014가단20244_판결서/0 saved.
# 광주지방법원 순천지원_2014가단20244_판결서/1 saved.
# 광주지방법원 순천지원_2014가단20244_판결서/2 saved.
# 광주지방법원 순천지원_2014가단20244_판결서/3 saved.
# 대구지법_2014재나105_판결서/0 saved.
# 대구지법_2014재나105_판결서/1 saved.
# 대구지법_2014재나105_판결서/2 saved.
# 대구지법_2014재나105_판결서/3 saved.
# 대구지법_2014재나105_판결서/4 saved.
# 서울고법_2016나662_판결서/0 saved.
# 서울고법_2016나662_판결서/1 saved.
# 서울고법_2016나662_판결서/2 saved.
# 서울고법_2016나662_판결서/3 saved.
# 서울고법_2016나662_판결서/4 saved.
# 서울고법_2016나662_판결서/5 saved.
# 서울고법_2016나662_판결서/6 saved.
# 서울고법_2016나662_판결서/7 saved.
# 서울고법_2016나662_판결서/8 saved.
# 의정부지법_2014가단10144_판결서/0 saved.
# 의정부지법_2014가단10144_판결서/1 saved.
# 의정부지법_2014가단10144_판결서/2 saved.
# 의정부지법_2014가단10144_판결서/3 saved.
# 의정부지법_2014가단10144_판결서/4 saved.
# 대전지방법원 홍성지원_2014가단12430_판결서/0 saved.
# 대전지방법원 홍성지원_2014가단12430_판결서/1 saved.
# 대전지방법원 홍성지원_2014가단12430_판결서/2 saved.
# 대전지방법원 홍성지원_2014가단12430_판결서/3 saved.
# 부산지법동부지원_2014가단23500_판결서/0 saved.
# 부산지법동부지원_2014가단23500_판결서/1 saved.
# 부산지법동부지원_2014가단23500_판결서/2 saved.
# 부산지법동부지원_2014가단23500_판결서/3 saved.
# 부산지법동부지원_2014가단23500_판결서/4 saved.
# 부산지법동부지원_2014가단23500_판결서/5 saved.
# 부산지법동부지원_2014가단23500_판결서/6 saved.
# 부산지법동부지원_2014가단23500_판결서/7 saved.
# 대구지법서부지원_2014가단35918_판결서/0 saved.
# 대구지법서부지원_2014가단35918_판결서/1 saved.
# 대전지방법원 홍성지원_2014가단11468_판결서/0 saved.
# 대전지방법원 홍성지원_2014가단11468_판결서/1 saved.
# 대전지방법원 홍성지원_2014가단11468_판결서/2 saved.
# 대전지방법원 홍성지원_2014가단11468_판결서/3 saved.
# 대전지법_2014가단33380_판결서/0 saved.
# 대전지법_2014가단33380_판결서/1 saved.
# 대전지법_2014가단33380_판결서/2 saved.
# 대전지법_2014가단33380_판결서/3 saved.
# 대전지법_2014가단33380_판결서/4 saved.
# 춘천지법_2013가단12054_판결서/0 saved.
# 춘천지법_2013가단12054_판결서/1 saved.
# 춘천지법_2013가단12054_판결서/2 saved.
# 춘천지법_2013가단12054_판결서/3 saved.
# 춘천지법_2013가단12054_판결서/4 saved.
# 춘천지법_2013가단12054_판결서/5 saved.
# 춘천지법_2013가단12054_판결서/6 saved.
# 춘천지법_2013가단12054_판결서/7 saved.
# 춘천지법_2013가단12054_판결서/8 saved.
# 춘천지법_2013가단12054_판결서/9 saved.
# 인천지법_2014가단246676_판결서/0 saved.
# 인천지법_2014가단246676_판결서/1 saved.
# 인천지법_2014가단246676_판결서/2 saved.
# 인천지법_2014가단246676_판결서/3 saved.
# 인천지법_2014가단246676_판결서/4 saved.
# 서울동부지법_2014가단46168_판결서/0 saved.
# 서울동부지법_2014가단46168_판결서/1 saved.
# 서울동부지법_2014가단46168_판결서/2 saved.
# 서울동부지법_2014가단46168_판결서/3 saved.
# 서울동부지법_2014가단46168_판결서/4 saved.
# 서울동부지법_2014가단46168_판결서/5 saved.
# 서울고법_2014나2036601_판결서/0 saved.
# 서울고법_2014나2036601_판결서/1 saved.
# 서울고법_2014나2036601_판결서/2 saved.
# 서울고법_2014나2036601_판결서/3 saved.
# 서울고법_2014나2036601_판결서/4 saved.
# 서울고법_2014나2036601_판결서/5 saved.
# 서울고법_2014나2036601_판결서/6 saved.
# 서울고법_2014나2036601_판결서/7 saved.
# 서울고법_2014나2036601_판결서/8 saved.
# 서울고법_2014나2036601_판결서/9 saved.
# 의정부지법_2013가합9588_판결서/0 saved.
# 의정부지법_2013가합9588_판결서/1 saved.
# 의정부지법_2013가합9588_판결서/2 saved.
# 의정부지법_2013가합9588_판결서/3 saved.
# 의정부지법_2013가합9588_판결서/4 saved.
# 의정부지법_2013가합9588_판결서/5 saved.
# 의정부지법_2013가합9588_판결서/6 saved.
# 수원지법_2014가합69361_판결서/0 saved.
# 수원지법_2014가합69361_판결서/1 saved.
# 수원지법_2014가합69361_판결서/2 saved.
# 수원지법_2014가합69361_판결서/3 saved.
# 수원지법_2014가합69361_판결서/4 saved.
# 수원지법_2014가합69361_판결서/5 saved.
# 수원지법_2014가합69361_판결서/6 saved.
# 수원지법_2014가합69361_판결서/7 saved.
# 수원지법_2014가합69361_판결서/8 saved.
# 수원지법_2014가합69361_판결서/9 saved.
# 대법원_2015다13584_판결서/0 saved.
# 대법원_2015다13584_판결서/1 saved.
# 대법원_2015다13584_판결서/2 saved.
# 대법원_2015다13584_판결서/3 saved.
# 인천지법_2016가단836_판결서/0 saved.
# 인천지법_2016가단836_판결서/1 saved.
# 인천지법_2016가단836_판결서/2 saved.
# 인천지법_2016가단836_판결서/3 saved.
# 충주지원_2016가합3065_판결서/0 saved.
# 충주지원_2016가합3065_판결서/1 saved.
# 충주지원_2016가합3065_판결서/2 saved.
# 충주지원_2016가합3065_판결서/3 saved.
# 충주지원_2016가합3065_판결서/4 saved.
# 충주지원_2016가합3065_판결서/5 saved.
# 충주지원_2016가합3065_판결서/6 saved.
# 충주지원_2016가합3065_판결서/7 saved.
# 충주지원_2016가합3065_판결서/8 saved.
# 충주지원_2016가합3065_판결서/9 saved.
# 강릉지원_2014가단7953_판결서/0 saved.
# 강릉지원_2014가단7953_판결서/1 saved.
# 강릉지원_2014가단7953_판결서/2 saved.
# 강릉지원_2014가단7953_판결서/3 saved.
# 강릉지원_2014가단7953_판결서/4 saved.
# 강릉지원_2014가단7953_판결서/5 saved.
# 강릉지원_2014가단7953_판결서/6 saved.
# 인천지법_2014가단15704_판결서/0 saved.
# 인천지법_2014가단15704_판결서/1 saved.
# 인천지법_2014가단15704_판결서/2 saved.
# 춘천지법_2014가단6414_판결서/0 saved.
# 춘천지법_2014가단6414_판결서/1 saved.
# 춘천지법_2014가단6414_판결서/2 saved.
# 수원지법_2014가단505174_판결서/0 saved.
# 수원지법_2014가단505174_판결서/1 saved.
# 수원지법_2014가단505174_판결서/2 saved.
# 수원지법_2014가단505174_판결서/3 saved.
# 수원지법_2014가단505174_판결서/4 saved.
# 수원지법_2014가단505174_판결서/5 saved.
# 서울서부지법_2014가단45396_판결서/0 saved.
# 서울서부지법_2014가단45396_판결서/1 saved.
# 서울서부지법_2014가단45396_판결서/2 saved.
# 서울서부지법_2014가단45396_판결서/3 saved.
# 서울서부지법_2014가단45396_판결서/4 saved.
# 인천지법_2013가합2487_판결서/0 saved.
# 인천지법_2013가합2487_판결서/1 saved.
# 인천지법_2013가합2487_판결서/2 saved.
# 인천지법_2013가합2487_판결서/3 saved.
# 인천지법_2013가합2487_판결서/4 saved.
# 인천지법_2013가합2487_판결서/5 saved.
# 인천지법_2013가합2487_판결서/6 saved.
# 인천지법_2013가합2487_판결서/7 saved.
# 인천지법_2013가합2487_판결서/8 saved.
# 인천지법_2013가합2487_판결서/9 saved.
# 인천지법_2013가합2487_판결서/10 saved.
# 창원지법_2014나13895_판결서/0 saved.
# 창원지법_2014나13895_판결서/1 saved.
# 창원지법_2014나13895_판결서/2 saved.
# 창원지법_2014나13895_판결서/3 saved.
# 창원지법_2014나13895_판결서/4 saved.
# 서울서부지법_2014가단18196_판결서/0 saved.
# 서울서부지법_2014가단18196_판결서/1 saved.
# 서울서부지법_2014가단18196_판결서/2 saved.
# 서울서부지법_2014가단18196_판결서/3 saved.
# 서울서부지법_2014가단18196_판결서/4 saved.
# 서울서부지법_2014가단18196_판결서/5 saved.
# 서울서부지법_2014가단18196_판결서/6 saved.
# 제주지법_2014가단17861_판결서/0 saved.
# 제주지법_2014가단17861_판결서/1 saved.
# 제주지법_2014가단17861_판결서/2 saved.
# 제주지법_2014가단17861_판결서/3 saved.
# 제주지법_2014가단17861_판결서/4 saved.
# 부산지법동부지원_2013가단210017_판결서/0 saved.
# 부산지법동부지원_2013가단210017_판결서/1 saved.
# 부산지법동부지원_2013가단210017_판결서/2 saved.
# 부산지법동부지원_2013가단210017_판결서/3 saved.
# 부산지법동부지원_2013가단210017_판결서/4 saved.
# 부산지법동부지원_2013가단210017_판결서/5 saved.
# 서울중앙지법_2015가합8280_판결서/0 saved.
# 서울중앙지법_2015가합8280_판결서/1 saved.
# 서울중앙지법_2015가합8280_판결서/2 saved.
# 서울중앙지법_2015가합8280_판결서/3 saved.
# 서울중앙지법_2015가합8280_판결서/4 saved.
# 청주지법_2013가단19373_판결서/0 saved.
# 청주지법_2013가단19373_판결서/1 saved.
# 청주지법_2013가단19373_판결서/2 saved.
# 청주지법_2013가단19373_판결서/3 saved.
# 청주지법_2013가단19373_판결서/4 saved.
# 청주지법_2013가단19373_판결서/5 saved.
# 청주지법_2013가단19373_판결서/6 saved.
# 청주지법_2013가단19373_판결서/7 saved.
# 청주지법_2013가단19373_판결서/8 saved.
# 춘천지법_2014가합1157_판결서/0 saved.
# 춘천지법_2014가합1157_판결서/1 saved.
# 춘천지법_2014가합1157_판결서/2 saved.
# 춘천지법_2014가합1157_판결서/3 saved.
# 춘천지법_2014가합1157_판결서/4 saved.
# 춘천지법_2014가합1157_판결서/5 saved.
# 춘천지법_2014가합1157_판결서/6 saved.
# 춘천지법_2014가합1157_판결서/7 saved.
# 춘천지법_2014가합1157_판결서/8 saved.
# 춘천지법_2014가합1157_판결서/9 saved.
# 춘천지법_2014가합1157_판결서/10 saved.
# 춘천지법_2014가합1157_판결서/11 saved.
# 서울행정법원_2015구합66837_판결서/0 saved.
# 서울행정법원_2015구합66837_판결서/1 saved.
# 서울행정법원_2015구합66837_판결서/2 saved.
# 서울행정법원_2015구합66837_판결서/3 saved.
# 서울행정법원_2015구합66837_판결서/4 saved.
# 서울행정법원_2015구합66837_판결서/5 saved.
# 서울행정법원_2015구합66837_판결서/6 saved.
# 서울행정법원_2015구합66837_판결서/7 saved.
# 서울행정법원_2015구합66837_판결서/8 saved.
# 서울행정법원_2015구합66837_판결서/9 saved.
# 서울행정법원_2015구합66837_판결서/10 saved.
# 서울행정법원_2015구합66837_판결서/11 saved.
# 인천지법_2014가합8284_판결서/0 saved.
# 인천지법_2014가합8284_판결서/1 saved.
# 인천지법_2014가합8284_판결서/2 saved.
# 인천지법_2014가합8284_판결서/3 saved.
# 인천지법_2014가합8284_판결서/4 saved.
# 인천지법_2014가합8284_판결서/5 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/0 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/1 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/2 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/3 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/4 saved.
# 대구지방법원 영덕지원_2014가단1213_판결서/5 saved.
# 대구지법서부지원_2014가단27603_판결서/0 saved.
# 대구지법서부지원_2014가단27603_판결서/1 saved.
# 대구지법서부지원_2014가단27603_판결서/2 saved.
# 대구지법서부지원_2014가단27603_판결서/3 saved.
# 대전지법_2014가단44298_판결서/0 saved.
# 대전지법_2014가단44298_판결서/1 saved.
# 대전지법_2014가단44298_판결서/2 saved.
# 제주지법_2013가단12753_판결서/0 saved.
# 제주지법_2013가단12753_판결서/1 saved.
# 제주지법_2013가단12753_판결서/2 saved.
# 제주지법_2013가단12753_판결서/3 saved.
# 제주지법_2013가단12753_판결서/4 saved.
# 제주지법_2013가단12753_판결서/5 saved.
# 제주지법_2013가단12753_판결서/6 saved.
# 제주지법_2013가단12753_판결서/7 saved.
# 제주지법_2013가단12753_판결서/8 saved.
# 제주지법_2013가단12753_판결서/9 saved.
# 제주지법_2013가단12753_판결서/10 saved.
# 제주지법_2013가단12753_판결서/11 saved.
# 제주지법_2013가단12753_판결서/12 saved.
# 제주지법_2013가단12753_판결서/13 saved.
# 제주지법_2013가단12753_판결서/14 saved.
# 제주지법_2013가단12753_판결서/15 saved.
# 서울중앙지법_2013가단275140_판결서/0 saved.
# 서울중앙지법_2013가단275140_판결서/1 saved.
# 서울중앙지법_2013가단275140_판결서/2 saved.
# 서울중앙지법_2013가단275140_판결서/3 saved.
# 서울중앙지법_2013가단275140_판결서/4 saved.
# 서울중앙지법_2013가단275140_판결서/5 saved.
# 서울중앙지법_2013가단275140_판결서/6 saved.
# 서울북부지법_2014나5973_판결서/0 saved.
# 서울북부지법_2014나5973_판결서/1 saved.
# 서울북부지법_2014나5973_판결서/2 saved.
# 서울북부지법_2014나5973_판결서/3 saved.
# 서울북부지법_2014나5973_판결서/4 saved.
# 서울북부지법_2014나5973_판결서/5 saved.
# 서울북부지법_2014나5973_판결서/6 saved.
# 광주지법_2014가단29150_판결서/0 saved.
# 광주지법_2014가단29150_판결서/1 saved.
# 광주지법_2014가단29150_판결서/2 saved.
# 광주지법_2014가단29150_판결서/3 saved.
# 광주지법_2014가단29150_판결서/4 saved.
# 광주지법_2014가단29150_판결서/5 saved.
# 서울고법_2014나2038447_판결서/0 saved.
# 서울고법_2014나2038447_판결서/1 saved.
# 서울고법_2014나2038447_판결서/2 saved.
# 서울고법_2014나2038447_판결서/3 saved.
# 대전지법_2014나107619_판결서/0 saved.
# 대전지법_2014나107619_판결서/1 saved.
# 대전지법_2014나107619_판결서/2 saved.
# 대전지법_2014나107619_판결서/3 saved.
# 대전지법_2014나107619_판결서/4 saved.
# 대전지법_2014나107619_판결서/5 saved.
# 대전지법_2014나107619_판결서/6 saved.
# 대전지법_2014나107619_판결서/7 saved.
# 대전지법_2014가단4429_판결서/0 saved.
# 대전지법_2014가단4429_판결서/1 saved.
# 대전지법_2014가단4429_판결서/2 saved.
# 대전지법_2014가단4429_판결서/3 saved.
# 대전지법_2014가단4429_판결서/4 saved.
# 대전지법_2014가단4429_판결서/5 saved.
# 대전지법_2014가단4429_판결서/6 saved.
# 대전지법_2014가단4429_판결서/7 saved.
# 대전지법_2014가단4429_판결서/8 saved.
# 대전지법_2014가단4429_판결서/9 saved.
# 대전지법_2014가단4429_판결서/10 saved.
# 대전지법_2014가단4429_판결서/11 saved.
# 대전지법_2014가단4429_판결서/12 saved.
# 대전지법_2014가단4429_판결서/13 saved.
# 대전지법_2014가단4429_판결서/14 saved.
# 대전지법_2014가단4429_판결서/15 saved.
# 대전지법_2014가단4429_판결서/16 saved.
# 대전지법_2014가단4429_판결서/17 saved.
# 전주지법_2014가단6512_판결서/0 saved.
# 전주지법_2014가단6512_판결서/1 saved.
# 전주지법_2014가단6512_판결서/2 saved.
# 전주지법_2014가단6512_판결서/3 saved.
# 전주지법_2014가단6512_판결서/4 saved.
# 전주지법_2014가단6512_판결서/5 saved.
# 전주지법_2014가단6512_판결서/6 saved.
# 광주지법_2014가단506619_판결서/0 saved.
# 광주지법_2014가단506619_판결서/1 saved.
# 광주지법_2014가단506619_판결서/2 saved.
# 광주지법_2014가단506619_판결서/3 saved.
# 광주지법_2014가단506619_판결서/4 saved.
# 광주지법_2014가단506619_판결서/5 saved.
# 광주지법_2014가단506619_판결서/6 saved.
# 광주지법_2014가단506619_판결서/7 saved.
# 광주지법_2014가단506619_판결서/8 saved.
# 광주지법_2014가단506619_판결서/9 saved.
# 의정부지법_2013가합73060_판결서/0 saved.
# 의정부지법_2013가합73060_판결서/1 saved.
# 의정부지법_2013가합73060_판결서/2 saved.
# 의정부지법_2013가합73060_판결서/3 saved.
# 의정부지법_2013가합73060_판결서/4 saved.
# 의정부지법_2013가합73060_판결서/5 saved.
# 의정부지법_2013가합73060_판결서/6 saved.
# 의정부지법_2013가합73060_판결서/7 saved.
# 의정부지법_2013가합73060_판결서/8 saved.
# 의정부지법_2013가합73060_판결서/9 saved.
# 의정부지법_2013가합73060_판결서/10 saved.
# 의정부지법_2013가합73060_판결서/11 saved.
# 의정부지법_2013가합73060_판결서/12 saved.
# 의정부지법_2013가합73060_판결서/13 saved.
# 의정부지법_2013가합73060_판결서/14 saved.
# 대전지방법원 공주지원_2013가합20065_별지9/0 saved.
# 서울동부지법_2014가합9029_판결서/0 saved.
# 서울동부지법_2014가합9029_판결서/1 saved.
# 서울동부지법_2014가합9029_판결서/2 saved.
# 서울동부지법_2014가합9029_판결서/3 saved.
# 평택지원_2014가합675_판결서/0 saved.
# 평택지원_2014가합675_판결서/1 saved.
# 평택지원_2014가합675_판결서/2 saved.
# 평택지원_2014가합675_판결서/3 saved.
# 평택지원_2014가합675_판결서/4 saved.
# 평택지원_2014가합675_판결서/5 saved.
# 평택지원_2014가합675_판결서/6 saved.
# 평택지원_2014가합675_판결서/7 saved.
# 광주지법_2013나11788_판결서/0 saved.
# 광주지법_2013나11788_판결서/1 saved.
# 광주지법_2013나11788_판결서/2 saved.
# 광주지법_2013나11788_판결서/3 saved.
# 광주지법_2013나11788_판결서/4 saved.
# 광주지법_2013나11788_판결서/5 saved.
# 광주지법_2013나11788_판결서/6 saved.
# 광주지법_2013나11788_판결서/7 saved.
# 광주지법_2013나11788_판결서/8 saved.
# 광주지법_2013나11788_판결서/9 saved.
# 광주지법_2013나11788_판결서/10 saved.
# 대전고법(청주)_2014나20920_판결서/0 saved.
# 대전고법(청주)_2014나20920_판결서/1 saved.
# 대전고법(청주)_2014나20920_판결서/2 saved.
# 대전고법(청주)_2014나20920_판결서/3 saved.
# 대전고법(청주)_2014나20920_판결서/4 saved.
# 대전고법(청주)_2014나20920_판결서/5 saved.
# 서울고법_2014나47506_판결서/0 saved.
# 서울고법_2014나47506_판결서/1 saved.
# 서울고법_2014나47506_판결서/2 saved.
# 서울고법_2014나47506_판결서/3 saved.
# 서울고법_2014나47506_판결서/4 saved.
# 서울고법_2014나47506_판결서/5 saved.
# 서울고법_2014나47506_판결서/6 saved.
# 서울고법_2014나47506_판결서/7 saved.
# 서울고법_2014나47506_판결서/8 saved.
# 서울고법_2014나47506_판결서/9 saved.
# 서울고법_2014나47506_판결서/10 saved.
# 서울고법_2014나47506_판결서/11 saved.
# 서울고법_2014나47506_판결서/12 saved.
# 서울고법_2014나47506_판결서/13 saved.
# 서울고법_2014나47506_판결서/14 saved.
# 서울고법_2014나47506_판결서/15 saved.
# 서울고법_2014나47506_판결서/16 saved.
# 서울고법_2014나47506_판결서/17 saved.
# 서울고법_2014나47506_판결서/18 saved.
# 서울고법_2014나47506_판결서/19 saved.
# 서울행정법원_2016구단5917_판결서/0 saved.
# 서울행정법원_2016구단5917_판결서/1 saved.
# 서울행정법원_2016구단5917_판결서/2 saved.
# 대전지법_2014가단29879_판결서/0 saved.
# 대전지법_2014가단29879_판결서/1 saved.
# 대전지법_2014가단29879_판결서/2 saved.
# 대전지법_2014가단29879_판결서/3 saved.
# 대전지법_2014가단29879_판결서/4 saved.
# 대법원_2013다200186_판결서/0 saved.
# 대법원_2013다200186_판결서/1 saved.
# 대법원_2013다200186_판결서/2 saved.
# 대법원_2013다200186_판결서/3 saved.
# 대법원_2013다200186_판결서/4 saved.
# 대법원_2013다200186_판결서/5 saved.
# 진주지원_2014가단12146_판결서/0 saved.
# 진주지원_2014가단12146_판결서/1 saved.
# 진주지원_2014가단12146_판결서/2 saved.
# 진주지원_2014가단12146_판결서/3 saved.
# 서울중앙지법_2014나28687_판결서/0 saved.
# 서울중앙지법_2014나28687_판결서/1 saved.
# 서울중앙지법_2014나28687_판결서/2 saved.
# 서울중앙지법_2014나28687_판결서/3 saved.
# 서울중앙지법_2014나28687_판결서/4 saved.
# 대전지법_2014가단225677_판결서/0 saved.
# 대전지법_2014가단225677_판결서/1 saved.
# 대전지법_2014가단225677_판결서/2 saved.
# 대전지법_2014가단225677_판결서/3 saved.
# 진주지원_2014가단35040_판결서/0 saved.
# 진주지원_2014가단35040_판결서/1 saved.
# 진주지원_2014가단35040_판결서/2 saved.
# 인천지법_2014나55055_판결서/0 saved.
# 인천지법_2014나55055_판결서/1 saved.
# 인천지법_2014나55055_판결서/2 saved.
# 인천지법_2014나55055_판결서/3 saved.
# 인천지법_2014나55055_판결서/4 saved.
# 인천지법_2014나55055_판결서/5 saved.
# 서울중앙지법_2016가단5000502_판결서/0 saved.
# 서울중앙지법_2016가단5000502_판결서/1 saved.
# 서울중앙지법_2016가단5000502_판결서/2 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/0 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/1 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/2 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/3 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/4 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/5 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/6 saved.
# 인천지방법원 부천지원_2014가단39918_판결서/7 saved.
# 대법원_2012다108368_판결서/0 saved.
# 대법원_2012다108368_판결서/1 saved.
# 대법원_2012다108368_판결서/2 saved.
# 전주지법_2014가단32405_판결서/0 saved.
# 전주지법_2014가단32405_판결서/1 saved.
# 전주지법_2014가단32405_판결서/2 saved.
# 전주지법_2014가단32405_판결서/3 saved.
# 전주지법_2014가단32405_판결서/4 saved.
# 전주지법_2014가단32405_판결서/5 saved.
# 전주지법_2014가단32405_판결서/6 saved.
# 전주지법_2014가단32405_판결서/7 saved.
# 전주지법_2014가단32405_판결서/8 saved.
# 전주지법_2014가단32405_판결서/9 saved.
# 전주지법_2014가단32405_판결서/10 saved.
# 전주지법_2014가단32405_판결서/11 saved.
# 전주지법_2014가단32405_판결서/12 saved.
# 서울중앙지법_2014나55757_판결서/0 saved.
# 서울중앙지법_2014나55757_판결서/1 saved.
# 서울중앙지법_2014나55757_판결서/2 saved.
# 서울중앙지법_2014나55757_판결서/3 saved.
# 통영지원_2013가단7454_판결서/0 saved.
# 통영지원_2013가단7454_판결서/1 saved.
# 통영지원_2013가단7454_판결서/2 saved.
# 통영지원_2013가단7454_판결서/3 saved.
# 통영지원_2013가단7454_판결서/4 saved.
# 통영지원_2013가단7454_판결서/5 saved.
# 통영지원_2013가단7454_판결서/6 saved.
# 통영지원_2013가단7454_판결서/7 saved.
# 통영지원_2013가단7454_판결서/8 saved.
# 통영지원_2013가단7454_판결서/9 saved.
# 성남지원_2013가합203365_판결서/0 saved.
# 성남지원_2013가합203365_판결서/1 saved.
# 성남지원_2013가합203365_판결서/2 saved.
# 성남지원_2013가합203365_판결서/3 saved.
# 성남지원_2013가합203365_판결서/4 saved.
# 부산지법동부지원_2016가합100279_판결서/0 saved.
# 부산지법동부지원_2016가합100279_판결서/1 saved.
# 부산지법동부지원_2016가합100279_판결서/2 saved.
# 부산지법동부지원_2016가합100279_판결서/3 saved.
# 부산지법동부지원_2016가합100279_판결서/4 saved.
# 부산지법동부지원_2016가합100279_판결서/5 saved.
# 부산지법동부지원_2016가합100279_판결서/6 saved.
# 부산지법동부지원_2016가합100279_판결서/7 saved.
# 부산지법동부지원_2016가합100279_판결서/8 saved.
# 부산지법동부지원_2016가합100279_판결서/9 saved.
# 부산지법동부지원_2016가합100279_판결서/10 saved.
# 부산지법동부지원_2016가합100279_판결서/11 saved.
# 부산지법동부지원_2016가합100279_판결서/12 saved.
# 부산지법동부지원_2016가합100279_판결서/13 saved.
# 부산지법동부지원_2016가합100279_판결서/14 saved.
# 부산지법동부지원_2016가합100279_판결서/15 saved.
# 부산지법동부지원_2016가합100279_판결서/16 saved.
# 부산지법동부지원_2016가합100279_판결서/17 saved.
# 부산지법동부지원_2016가합100279_판결서/18 saved.
# 부산지법동부지원_2016가합100279_판결서/19 saved.
# 부산지법동부지원_2016가합100279_판결서/20 saved.
# 부산지법동부지원_2016가합100279_판결서/21 saved.
# 부산지법동부지원_2016가합100279_판결서/22 saved.
# 부산지법동부지원_2016가합100279_판결서/23 saved.
# 부산지법동부지원_2016가합100279_판결서/24 saved.
# 부산지법동부지원_2016가합100279_판결서/25 saved.
# 부산지법동부지원_2016가합100279_판결서/26 saved.
# 부산지법동부지원_2016가합100279_판결서/27 saved.
# 부산지법동부지원_2016가합100279_판결서/28 saved.
# 부산지법동부지원_2016가합100279_판결서/29 saved.
# 부산지법동부지원_2016가합100279_판결서/30 saved.
# 부산고법_2014나7735_판결서/0 saved.
# 부산고법_2014나7735_판결서/1 saved.
# 부산고법_2014나7735_판결서/2 saved.
# 부산고법_2014나7735_판결서/3 saved.
# 부산고법_2014나7735_판결서/4 saved.
# 부산고법_2014나7735_판결서/5 saved.
# 부산고법_2014나7735_판결서/6 saved.
# 부산고법_2014나7735_판결서/7 saved.
# 부산고법_2014나7735_판결서/8 saved.
# 부산고법_2014나7735_판결서/9 saved.
# 부산고법_2014나7735_판결서/10 saved.
# 부산고법_2014나7735_판결서/11 saved.
# 부산고법_2014나7735_판결서/12 saved.
# 대전고법_2013나11568_판결서/0 saved.
# 대전고법_2013나11568_판결서/1 saved.
# 대전고법_2013나11568_판결서/2 saved.
# 대전고법_2013나11568_판결서/3 saved.
# 대전고법_2013나11568_판결서/4 saved.
# 대전고법_2013나11568_판결서/5 saved.
# 대전고법_2013나11568_판결서/6 saved.
# 대전고법_2013나11568_판결서/7 saved.
# 대전고법_2013나11568_판결서/8 saved.
# 대전고법_2013나11568_판결서/9 saved.
# 대전고법_2013나11568_판결서/10 saved.
# 대전고법_2013나11568_판결서/11 saved.
# 대전고법_2013나11568_판결서/12 saved.
# 서울중앙지법_2013가단5123367_판결서/0 saved.
# 서울중앙지법_2013가단5123367_판결서/1 saved.
# 서울중앙지법_2013가단5123367_판결서/2 saved.
# 서울중앙지법_2013가단5123367_판결서/3 saved.
# 서울중앙지법_2013가단5123367_판결서/4 saved.
# 서울중앙지법_2013가단5123367_판결서/5 saved.
# 수원지법_2014구합54616_판결서/0 saved.
# 수원지법_2014구합54616_판결서/1 saved.
# 수원지법_2014구합54616_판결서/2 saved.
# 수원지법_2014구합54616_판결서/3 saved.
# 수원지법_2014구합54616_판결서/4 saved.
# 수원지법_2014구합54616_판결서/5 saved.
# 수원지법_2014구합54616_판결서/6 saved.
# 수원지법_2014구합54616_판결서/7 saved.
# 수원지법_2014구합54616_판결서/8 saved.
# 수원지법_2014구합54616_판결서/9 saved.
# 수원지법_2014구합54616_판결서/10 saved.
# 서울중앙지법_2014가합542134_판결서/0 saved.
# 서울중앙지법_2014가합542134_판결서/1 saved.
# 서울중앙지법_2014가합542134_판결서/2 saved.
# 서울중앙지법_2014가합542134_판결서/3 saved.
# 서울중앙지법_2014가합542134_판결서/4 saved.
# 서울중앙지법_2014가합542134_판결서/5 saved.
# 서울중앙지법_2014가합542134_판결서/6 saved.
# 서울중앙지법_2014가합542134_판결서/7 saved.
# 서울중앙지법_2014가합542134_판결서/8 saved.
# 서울중앙지법_2014가합542134_판결서/9 saved.
# 서울중앙지법_2014가합542134_판결서/10 saved.
# 서울중앙지법_2014가합542134_판결서/11 saved.
# 서울중앙지법_2014가합542134_판결서/12 saved.
# 서울중앙지법_2014가합542134_판결서/13 saved.
# 대구지법서부지원_2014가단19565_경정결정2/0 saved.
# 인천지법_2014가단220285_판결서/0 saved.
# 인천지법_2014가단220285_판결서/1 saved.
# 인천지법_2014가단220285_판결서/2 saved.
# 인천지법_2014가단220285_판결서/3 saved.
# 인천지법_2014가단220285_판결서/4 saved.
# 인천지법_2014가단220285_판결서/5 saved.
# 인천지법_2014가단220285_판결서/6 saved.
# 인천지법_2014가단220285_판결서/7 saved.
# 청주지법_2015나336 (1)_판결서/0 saved.
# 청주지법_2015나336 (1)_판결서/1 saved.
# 청주지법_2015나336 (1)_판결서/2 saved.
# 서울중앙지법_2014가단228462_판결서/0 saved.
# 서울중앙지법_2014가단228462_판결서/1 saved.
# 서울중앙지법_2014가단228462_판결서/2 saved.
# 서울중앙지법_2014가단228462_판결서/3 saved.
# 서울중앙지법_2012가단5037117_판결서/0 saved.
# 서울중앙지법_2012가단5037117_판결서/1 saved.
# 서울중앙지법_2012가단5037117_판결서/2 saved.
# 서울중앙지법_2012가단5037117_판결서/3 saved.
# 서울중앙지법_2012가단5037117_판결서/4 saved.
# 서울중앙지법_2012가단5037117_판결서/5 saved.
# 서울중앙지법_2012가단5037117_판결서/6 saved.
# 서울중앙지법_2012가단5037117_판결서/7 saved.
# 서울중앙지법_2012가단5037117_판결서/8 saved.
# 대전지방법원 공주지원_2013가합20065_별지17/0 saved.
# 안산지원_2014가단14306_판결서/0 saved.
# 안산지원_2014가단14306_판결서/1 saved.
# 안산지원_2014가단14306_판결서/2 saved.
# 안산지원_2014가단14306_판결서/3 saved.
# 안산지원_2014가단14306_판결서/4 saved.
# 안산지원_2014가단14306_판결서/5 saved.
# 안산지원_2014가단14306_판결서/6 saved.
# 안산지원_2014가단14306_판결서/7 saved.
# 평택지원_2014가합2350_판결서/0 saved.
# 평택지원_2014가합2350_판결서/1 saved.
# 평택지원_2014가합2350_판결서/2 saved.
# 평택지원_2014가합2350_판결서/3 saved.
# 평택지원_2014가합2350_판결서/4 saved.
# 평택지원_2014가합2350_판결서/5 saved.
# 대구지방법원 의성지원_2015가합10003_판결서/0 saved.
# 대구지방법원 의성지원_2015가합10003_판결서/1 saved.
# 대구지방법원 의성지원_2015가합10003_판결서/2 saved.
# 대구지방법원 의성지원_2015가합10003_판결서/3 saved.
# 대구지법_2014가단46188_판결서/0 saved.
# 대구지법_2014가단46188_판결서/1 saved.
# 대구지법_2014가단46188_판결서/2 saved.
# 대구지법_2014가단46188_판결서/3 saved.
# 대구지법_2014가단46188_판결서/4 saved.
# 대구지법_2014가단46188_판결서/5 saved.
# 대구지법_2014가단46188_판결서/6 saved.
# 대구지법_2014가단46188_판결서/7 saved.
# 대구지법_2014가단46188_판결서/8 saved.
# 의정부지법_2014가단20868_판결서/0 saved.
# 의정부지법_2014가단20868_판결서/1 saved.
# 의정부지법_2014가단20868_판결서/2 saved.
# 의정부지법_2014가단20868_판결서/3 saved.
# 의정부지법_2014가단20868_판결서/4 saved.
# 수원지법_2014가합4562_판결서/0 saved.
# 수원지법_2014가합4562_판결서/1 saved.
# 수원지법_2014가합4562_판결서/2 saved.
# 수원지법_2014가합4562_판결서/3 saved.
# 수원지법_2014가합4562_판결서/4 saved.
# 서울북부지법_2013가합7329_판결서/0 saved.
# 서울북부지법_2013가합7329_판결서/1 saved.
# 서울북부지법_2013가합7329_판결서/2 saved.
# 서울북부지법_2013가합7329_판결서/3 saved.
# 서울북부지법_2013가합7329_판결서/4 saved.
# 서울북부지법_2013가합7329_판결서/5 saved.
# 서울북부지법_2013가합7329_판결서/6 saved.
# 서울북부지법_2013가합7329_판결서/7 saved.
# 서울북부지법_2013가합7329_판결서/8 saved.
# 서울중앙지법_2014나39809_판결서/0 saved.
# 서울중앙지법_2014나39809_판결서/1 saved.
# 서울중앙지법_2014나39809_판결서/2 saved.
# 서울중앙지법_2014나39809_판결서/3 saved.
# 서울중앙지법_2014나39809_판결서/4 saved.
# 서울중앙지법_2014나39809_판결서/5 saved.
# 서울중앙지법_2014나39809_판결서/6 saved.
# 전주지법_2014가단27687_판결서/0 saved.
# 전주지법_2014가단27687_판결서/1 saved.
# 전주지법_2014가단27687_판결서/2 saved.
# 전주지법_2014가단27687_판결서/3 saved.
# 대전고법(청주)_2014나1509_판결서/0 saved.
# 대전고법(청주)_2014나1509_판결서/1 saved.
# 대전고법(청주)_2014나1509_판결서/2 saved.
# 대전고법(청주)_2014나1509_판결서/3 saved.
# 대전고법(청주)_2014나1509_판결서/4 saved.
# 서울중앙지법_2013가합48604_판결서/0 saved.
# 서울중앙지법_2013가합48604_판결서/1 saved.
# 서울중앙지법_2013가합48604_판결서/2 saved.
# 서울중앙지법_2013가합48604_판결서/3 saved.
# 서울중앙지법_2013가합48604_판결서/4 saved.
# 서울중앙지법_2013가합48604_판결서/5 saved.
# 서울중앙지법_2013가합48604_판결서/6 saved.
# 서울중앙지법_2013가합48604_판결서/7 saved.
# 서울중앙지법_2013가합48604_판결서/8 saved.
# 서울중앙지법_2013가합48604_판결서/9 saved.
# 서울중앙지법_2013가합48604_판결서/10 saved.
# 서울중앙지법_2013가합48604_판결서/11 saved.
# 광주지법_2014가단513198_판결서/0 saved.
# 광주지법_2014가단513198_판결서/1 saved.
# 광주지법_2014가단513198_판결서/2 saved.
# 광주지법_2014가단513198_판결서/3 saved.
# 광주지법_2014가단513198_판결서/4 saved.
# 광주지법_2014가단513198_판결서/5 saved.
# 광주지법_2014가단513198_판결서/6 saved.
# 광주지법_2014가단513198_판결서/7 saved.
# 광주지법_2014가단513198_판결서/8 saved.
# 광주지법_2014가단513198_판결서/9 saved.
# 광주지법_2014가단513198_판결서/10 saved.
# 광주지법_2014가단513198_판결서/11 saved.
# 광주지법_2014가단513198_판결서/12 saved.
# 광주지법_2014가단513198_판결서/13 saved.
# 광주지법_2014가단513198_판결서/14 saved.
# 광주지법_2014가단513198_판결서/15 saved.
# 광주지법_2014가단513198_판결서/16 saved.
# 대전지방법원 공주지원_2013가합20065_별지10/0 saved.
# 서울중앙지법_2014가단220550_판결서/0 saved.
# 서울중앙지법_2014가단220550_판결서/1 saved.
# 서울중앙지법_2014가단220550_판결서/2 saved.
# 서울중앙지법_2014가단220550_판결서/3 saved.
# 서울중앙지법_2014가단220550_판결서/4 saved.
# 서울중앙지법_2014가합7150_판결서/0 saved.
# 서울중앙지법_2014가합7150_판결서/1 saved.
# 서울중앙지법_2014가합7150_판결서/2 saved.
# 서울중앙지법_2014가합7150_판결서/3 saved.
# 서울중앙지법_2014가합7150_판결서/4 saved.
# 서울중앙지법_2014가합7150_판결서/5 saved.
# 서울중앙지법_2014가합7150_판결서/6 saved.
# 서울중앙지법_2014가합7150_판결서/7 saved.
# 서울중앙지법_2014가합7150_판결서/8 saved.
# 서울중앙지법_2014가합7150_판결서/9 saved.
# 서울중앙지법_2014가합7150_판결서/10 saved.
# 서울중앙지법_2014가합7150_판결서/11 saved.
# 서울중앙지법_2014가합7150_판결서/12 saved.
# 서울중앙지법_2014가합7150_판결서/13 saved.
# 서울중앙지법_2014가합7150_판결서/14 saved.
# 서울중앙지법_2014가합7150_판결서/15 saved.
# 울산지법_2014가단18734_판결서/0 saved.
# 울산지법_2014가단18734_판결서/1 saved.
# 울산지법_2014가단18734_판결서/2 saved.
# 울산지법_2014가단18734_판결서/3 saved.
# 울산지법_2014가단18734_판결서/4 saved.
# 인천지법_2014가합53796_판결서/0 saved.
# 인천지법_2014가합53796_판결서/1 saved.
# 인천지법_2014가합53796_판결서/2 saved.
# 인천지법_2014가합53796_판결서/3 saved.
# 인천지법_2014가합53796_판결서/4 saved.
# 인천지법_2014가합53796_판결서/5 saved.
# 인천지법_2014가합53796_판결서/6 saved.
# 부산지법동부지원_2014가단214313_판결서/0 saved.
# 부산지법동부지원_2014가단214313_판결서/1 saved.
# 부산지법동부지원_2014가단214313_판결서/2 saved.
# 부산지법동부지원_2014가단214313_판결서/3 saved.
# 부산지법동부지원_2014가단214313_판결서/4 saved.
# 대전지방법원 공주지원_2014가합341_판결서/0 saved.
# 대전지방법원 공주지원_2014가합341_판결서/1 saved.
# 대전지방법원 공주지원_2014가합341_판결서/2 saved.
# 대전지방법원 공주지원_2014가합341_판결서/3 saved.
# 대전지방법원 서산지원_2014가단5755_판결서/0 saved.
# 대전지방법원 서산지원_2014가단5755_판결서/1 saved.
# 대전지방법원 서산지원_2014가단5755_판결서/2 saved.
# 대전지방법원 서산지원_2014가단5755_판결서/3 saved.
# 서울남부지법_2015나50397_경정결정/0 saved.
# 서울남부지법_2015나50397_경정결정/1 saved.
# 강릉지원_2013가단23514_판결서/0 saved.
# 강릉지원_2013가단23514_판결서/1 saved.
# 강릉지원_2013가단23514_판결서/2 saved.
# 강릉지원_2013가단23514_판결서/3 saved.
# 강릉지원_2013가단23514_판결서/4 saved.
# 강릉지원_2013가단23514_판결서/5 saved.
# 강릉지원_2013가단23514_판결서/6 saved.
# 강릉지원_2013가단23514_판결서/7 saved.
# 강릉지원_2013가단23514_판결서/8 saved.
# 대전지법_2014가합106292_판결서/0 saved.
# 대전지법_2014가합106292_판결서/1 saved.
# 대전지법_2014가합106292_판결서/2 saved.
# 대전지법_2014가합106292_판결서/3 saved.
# 대전지법_2014가합106292_판결서/4 saved.
# 대전지법_2014가합106292_판결서/5 saved.
# 대전지법_2014가합106292_판결서/6 saved.
# 대전지법_2014가합106292_판결서/7 saved.
# 대전지법_2014가합106292_판결서/8 saved.
# 대전지법_2014가합106292_판결서/9 saved.
# 대전지법_2014가합106292_판결서/10 saved.
# 서울중앙지법_2014가단246316_판결서/0 saved.
# 서울중앙지법_2014가단246316_판결서/1 saved.
# 서울중앙지법_2014가단246316_판결서/2 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/0 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/1 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/2 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/3 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/4 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/5 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/6 saved.
# 인천지방법원 부천지원_2014가단30614_판결서/7 saved.
# 인천지방법원 부천지원_2014가합283_판결서/0 saved.
# 인천지방법원 부천지원_2014가합283_판결서/1 saved.
# 인천지방법원 부천지원_2014가합283_판결서/2 saved.
# 인천지방법원 부천지원_2014가합283_판결서/3 saved.
# 인천지방법원 부천지원_2014가합283_판결서/4 saved.
# 인천지방법원 부천지원_2014가합283_판결서/5 saved.
# 인천지방법원 부천지원_2014가합283_판결서/6 saved.
# 인천지방법원 부천지원_2014가합283_판결서/7 saved.
# 인천지방법원 부천지원_2014가합283_판결서/8 saved.
# 인천지방법원 부천지원_2014가합283_판결서/9 saved.
# 대전지법_2014가단201763_판결서/0 saved.
# 대전지법_2014가단201763_판결서/1 saved.
# 대전지법_2014가단201763_판결서/2 saved.
# 대전지법_2014가단201763_판결서/3 saved.
# 대전지법_2014가단201763_판결서/4 saved.
# 대전지법_2014가단201763_판결서/5 saved.
# 대전지법_2014가단201763_판결서/6 saved.
# 의정부지법_2014가단50197_판결서/0 saved.
# 의정부지법_2014가단50197_판결서/1 saved.
# 의정부지법_2014가단50197_판결서/2 saved.
# 수원지법_2014가합1846_판결서/0 saved.
# 수원지법_2014가합1846_판결서/1 saved.
# 수원지법_2014가합1846_판결서/2 saved.
# 수원지법_2014가합1846_판결서/3 saved.
# 진주지원_2014가단1481_판결서/0 saved.
# 진주지원_2014가단1481_판결서/1 saved.
# 진주지원_2014가단1481_판결서/2 saved.
# 진주지원_2014가단1481_판결서/3 saved.
# 진주지원_2014가단1481_판결서/4 saved.
# 진주지원_2014가단1481_판결서/5 saved.
# 진주지원_2014가단1481_판결서/6 saved.
# 진주지원_2014가단1481_판결서/7 saved.
# 진주지원_2014가단1481_판결서/8 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/0 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/1 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/2 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/3 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/4 saved.
# 대전지방법원 공주지원_2014가합20437_판결서/5 saved.
# 서울동부지법_2014가단34776_판결서/0 saved.
# 서울동부지법_2014가단34776_판결서/1 saved.
# 서울동부지법_2014가단34776_판결서/2 saved.
# 서울동부지법_2014가단34776_판결서/3 saved.
# 서울동부지법_2014가단34776_판결서/4 saved.
# 서울서부지법_2014나32483_판결서/0 saved.
# 서울서부지법_2014나32483_판결서/1 saved.
# 서울서부지법_2014나32483_판결서/2 saved.
# 서울서부지법_2014나32483_판결서/3 saved.
# 서울서부지법_2014나32483_판결서/4 saved.
# 서울서부지법_2014나32483_판결서/5 saved.
# 서울서부지법_2014나32483_판결서/6 saved.
# 서울서부지법_2014나32483_판결서/7 saved.
# 서울서부지법_2014나32483_판결서/8 saved.
# 서울서부지법_2014나32483_판결서/9 saved.
# 서울중앙지법_2014나18147_판결서/0 saved.
# 서울중앙지법_2014나18147_판결서/1 saved.
# 서울중앙지법_2014나18147_판결서/2 saved.
# 서울중앙지법_2014나18147_판결서/3 saved.
# 서울중앙지법_2014나18147_판결서/4 saved.
# 서울중앙지법_2014나18147_판결서/5 saved.
# 서울중앙지법_2014나18147_판결서/6 saved.
# 서울중앙지법_2014나18147_판결서/7 saved.
# 서울중앙지법_2014나18147_판결서/8 saved.
# 서울중앙지법_2014나18147_판결서/9 saved.
# 서울중앙지법_2014나18147_판결서/10 saved.
# 서울중앙지법_2014나18147_판결서/11 saved.
# 서울중앙지법_2014나18147_판결서/12 saved.
# 서울중앙지법_2014나18147_판결서/13 saved.
# 서울중앙지법_2014나18147_판결서/14 saved.
# 서울중앙지법_2014나18147_판결서/15 saved.
# 서울중앙지법_2014나18147_판결서/16 saved.
# 서울중앙지법_2014나18147_판결서/17 saved.
# 서울중앙지법_2014나18147_판결서/18 saved.
# 서울중앙지법_2014나18147_판결서/19 saved.
# 서울중앙지법_2014나18147_판결서/20 saved.
# 의정부지법_2013가단161878_판결서/0 saved.
# 의정부지법_2013가단161878_판결서/1 saved.
# 의정부지법_2013가단161878_판결서/2 saved.
# 의정부지법_2013가단161878_판결서/3 saved.
# 의정부지법_2013가단161878_판결서/4 saved.
# 의정부지법_2013가단161878_판결서/5 saved.
# 대구지법_2012가합12058_판결서/0 saved.
# 대구지법_2012가합12058_판결서/1 saved.
# 대구지법_2012가합12058_판결서/2 saved.
# 대구지법_2012가합12058_판결서/3 saved.
# 대구지법_2012가합12058_판결서/4 saved.
# 대구지법_2012가합12058_판결서/5 saved.
# 대구지법_2012가합12058_판결서/6 saved.
# 대구지법_2012가합12058_판결서/7 saved.
# 대구지법_2012가합12058_판결서/8 saved.
# 대구지법_2012가합12058_판결서/9 saved.
# 대구지법_2012가합12058_판결서/10 saved.
# 대구지법_2012가합12058_판결서/11 saved.
# 대구지법_2012가합12058_판결서/12 saved.
# 대구지법_2012가합12058_판결서/13 saved.
# 대구지법_2012가합12058_판결서/14 saved.
# 대구지법_2012가합12058_판결서/15 saved.
# 대구지법_2012가합12058_판결서/16 saved.
# 대구지법_2012가합12058_판결서/17 saved.
# 대구지법_2012가합12058_판결서/18 saved.
# 대구지법_2012가합12058_판결서/19 saved.
# 대법원_2013다6421_판결서/0 saved.
# 대법원_2013다6421_판결서/1 saved.
# 대법원_2013다6421_판결서/2 saved.
# 대법원_2013다6421_판결서/3 saved.
# 대법원_2013다6421_판결서/4 saved.
# 대법원_2013다6421_판결서/5 saved.
# 대법원_2013다6421_판결서/6 saved.
# 서울중앙지법_2014나35678_판결서/0 saved.
# 서울중앙지법_2014나35678_판결서/1 saved.
# 서울중앙지법_2014나35678_판결서/2 saved.
# 서울중앙지법_2014가단5347559_판결서/0 saved.
# 서울중앙지법_2014가단5347559_판결서/1 saved.
# 서울중앙지법_2014가단5347559_판결서/2 saved.
# 서울중앙지법_2014가단5347559_판결서/3 saved.
# 인천지법_2014가합51301_판결서/0 saved.
# 인천지법_2014가합51301_판결서/1 saved.
# 인천지법_2014가합51301_판결서/2 saved.
# 인천지법_2014가합51301_판결서/3 saved.
# 인천지법_2014가합51301_판결서/4 saved.
# 인천지법_2014가합51301_판결서/5 saved.
# 인천지법_2014가합51301_판결서/6 saved.
# 안양지원_2014가단110233_판결서/0 saved.
# 안양지원_2014가단110233_판결서/1 saved.
# 안양지원_2014가단110233_판결서/2 saved.
# 안양지원_2014가단110233_판결서/3 saved.
# 원주지원_2013가단7386_판결서/0 saved.
# 원주지원_2013가단7386_판결서/1 saved.
# 원주지원_2013가단7386_판결서/2 saved.
# 원주지원_2013가단7386_판결서/3 saved.
# 원주지원_2013가단7386_판결서/4 saved.
# 서울남부지법_2014가단50689_판결서/0 saved.
# 서울남부지법_2014가단50689_판결서/1 saved.
# 서울남부지법_2014가단50689_판결서/2 saved.
# 서울남부지법_2014가단50689_판결서/3 saved.
# 서울남부지법_2014가단50689_판결서/4 saved.
# 서울남부지법_2014가단50689_판결서/5 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/0 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/1 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/2 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/3 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/4 saved.
# 대구지방법원 김천지원_2013가단14008_판결서/5 saved.
# 대구지법_2014가단124347_판결서/0 saved.
# 대구지법_2014가단124347_판결서/1 saved.
# 대구지법_2014가단124347_판결서/2 saved.
# 대구지법_2014가단124347_판결서/3 saved.
# 대구지법_2014가단124347_판결서/4 saved.
# 대구지법_2014가단124347_판결서/5 saved.
# 서울중앙지법_2013가합67766_별지2/0 saved.
# 서울중앙지법_2013가합67766_별지2/1 saved.
# 서울중앙지법_2013가합67766_별지2/2 saved.
# 서울중앙지법_2013가합67766_별지2/3 saved.
# 서울중앙지법_2013가합67766_별지2/4 saved.
# 서울중앙지법_2013가합67766_별지2/5 saved.
# 서울중앙지법_2013가합67766_별지2/6 saved.
# 서울중앙지법_2013가합67766_별지2/7 saved.
# 서울중앙지법_2013가합67766_별지2/8 saved.
# 서울중앙지법_2013가합67766_별지2/9 saved.
# 서울중앙지법_2013가합67766_별지2/10 saved.
# 서울중앙지법_2013가합67766_별지2/11 saved.
# 서울중앙지법_2013가합67766_별지2/12 saved.
# 서울중앙지법_2013가합67766_별지2/13 saved.
# 서울중앙지법_2013가합67766_별지2/14 saved.
# 서울중앙지법_2013가합67766_별지2/15 saved.
# 서울중앙지법_2013가합67766_별지2/16 saved.
# 서울중앙지법_2013가합67766_별지2/17 saved.
# 서울중앙지법_2013가합67766_별지2/18 saved.
# 서울서부지법_2014가단36934_판결서/0 saved.
# 서울서부지법_2014가단36934_판결서/1 saved.
# 서울서부지법_2014가단36934_판결서/2 saved.
# 서울서부지법_2014가단36934_판결서/3 saved.
# 서울서부지법_2014가단36934_판결서/4 saved.
# 서울중앙지법_2014가단127941_판결서/0 saved.
# 서울중앙지법_2014가단127941_판결서/1 saved.
# 서울중앙지법_2014가단127941_판결서/2 saved.
# 서울중앙지법_2014가단127941_판결서/3 saved.
# 서울중앙지법_2014가단127941_판결서/4 saved.
# 서울중앙지법_2014가단127941_판결서/5 saved.
# 서울중앙지법_2014가단127941_판결서/6 saved.
# 서울중앙지법_2014가단127941_판결서/7 saved.
# 서울북부지법_2014가합5757_판결서/0 saved.
# 서울북부지법_2014가합5757_판결서/1 saved.
# 서울북부지법_2014가합5757_판결서/2 saved.
# 서울북부지법_2014가합5757_판결서/3 saved.
# 인천지법_2015나632_판결서/0 saved.
# 인천지법_2015나632_판결서/1 saved.
# 인천지법_2015나632_판결서/2 saved.
# 인천지법_2015나632_판결서/3 saved.
# 인천지법_2015나632_판결서/4 saved.
# 인천지법_2015나632_판결서/5 saved.
# 인천지법_2015나632_판결서/6 saved.
# 창원지법_2014나8091_판결서/0 saved.
# 창원지법_2014나8091_판결서/1 saved.
# 창원지법_2014나8091_판결서/2 saved.
# 창원지법_2014나8091_판결서/3 saved.
# 창원지법_2014나8091_판결서/4 saved.
# 창원지법_2014나8091_판결서/5 saved.
# 서울동부지법_2013가단122959_판결서/0 saved.
# 서울동부지법_2013가단122959_판결서/1 saved.
# 서울동부지법_2013가단122959_판결서/2 saved.
# 서울고법_2014나39093_판결서/0 saved.
# 서울고법_2014나39093_판결서/1 saved.
# 서울고법_2014나39093_판결서/2 saved.
# 서울고법_2014나39093_판결서/3 saved.
# 서울고법_2014나39093_판결서/4 saved.
# 서울고법_2014나39093_판결서/5 saved.
# 서울고법_2014나39093_판결서/6 saved.
# 서울고법_2014나39093_판결서/7 saved.
# 서울고법_2014나39093_판결서/8 saved.
# 서울고법_2014나39093_판결서/9 saved.
# 서울고법_2014나39093_판결서/10 saved.
# 서울고법_2014나39093_판결서/11 saved.
# 서울고법_2014나39093_판결서/12 saved.
# 서울고법_2014나39093_판결서/13 saved.
# 서울고법_2014나39093_판결서/14 saved.
# 서울고법_2014나39093_판결서/15 saved.
# 서울고법_2014나39093_판결서/16 saved.
# 서울고법_2014나39093_판결서/17 saved.
# 서울고법_2014나39093_판결서/18 saved.
# 서울고법_2014나39093_판결서/19 saved.
# 부산지법_2013가합14104_판결서/0 saved.
# 부산지법_2013가합14104_판결서/1 saved.
# 부산지법_2013가합14104_판결서/2 saved.
# 부산지법_2013가합14104_판결서/3 saved.
# 부산지법_2013가합14104_판결서/4 saved.
# 부산지법_2013가합14104_판결서/5 saved.
# 부산지법_2013가합14104_판결서/6 saved.
# 부산지법_2013가합14104_판결서/7 saved.
# 부산지법_2013가합14104_판결서/8 saved.
# 부산지법_2013가합14104_판결서/9 saved.
# 부산지법_2013가합14104_판결서/10 saved.
# 부산지법_2013가합14104_판결서/11 saved.
# 부산지법_2013가합14104_판결서/12 saved.
# 의정부지법_2013가단37166_판결서/0 saved.
# 의정부지법_2013가단37166_판결서/1 saved.
# 의정부지법_2013가단37166_판결서/2 saved.
# 의정부지법_2013가단37166_판결서/3 saved.
# 의정부지법_2013가단37166_판결서/4 saved.
# 대구지법_2015가단4389_판결서/0 saved.
# 대구지법_2015가단4389_판결서/1 saved.
# 대구지법_2015가단4389_판결서/2 saved.
# 대구지법_2015가단4389_판결서/3 saved.
# 인천지법_2013가합12644_판결서/0 saved.
# 인천지법_2013가합12644_판결서/1 saved.
# 인천지법_2013가합12644_판결서/2 saved.
# 인천지법_2013가합12644_판결서/3 saved.
# 인천지법_2013가합12644_판결서/4 saved.
# 인천지법_2013가합12644_판결서/5 saved.
# 인천지법_2013가합12644_판결서/6 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/0 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/1 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/2 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/3 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/4 saved.
# 대구지방법원 포항지원_2014가단4123_판결서/5 saved.
# 울산지법_2014가단29369_판결서/0 saved.
# 울산지법_2014가단29369_판결서/1 saved.
# 울산지법_2014가단29369_판결서/2 saved.
# 울산지법_2014가단29369_판결서/3 saved.
# 울산지법_2014가단29369_판결서/4 saved.
# 서울남부지법_2014가단239369_판결서/0 saved.
# 서울남부지법_2014가단239369_판결서/1 saved.
# 서울남부지법_2014가단239369_판결서/2 saved.
# 인천지법_2014가단207961_판결서/0 saved.
# 인천지법_2014가단207961_판결서/1 saved.
# 인천지법_2014가단207961_판결서/2 saved.
# 인천지법_2014가단207961_판결서/3 saved.
# 인천지법_2014가단207961_판결서/4 saved.
# 인천지법_2014가단207961_판결서/5 saved.
# 인천지법_2014가단207961_판결서/6 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/0 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/1 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/2 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/3 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/4 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/5 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/6 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/7 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/8 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/9 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/10 saved.
# 대전지방법원 서산지원_2014가단2695_판결서/11 saved.
# ...
# 수원지법_2014가단521237_판결서/4 saved.
# 수원지법_2014가단521237_판결서/5 saved.
# 대전지방법원 공주지원_2013가합20065_별지3/0 saved.
# 대전지방법원 공주지원_2013가합20065_별지3/1 saved.
# 대전지방법원 공주지원_2013가합20065_별지3/2 saved.
# 부산고법_2014나8202_판결서/0 saved.
# 부산고법_2014나8202_판결서/1 saved.
# 부산고법_2014나8202_판결서/2 saved.
# 대전지법_2014나104405_판결서/0 saved.
# 대전지법_2014나104405_판결서/1 saved.
# 대전지법_2014나104405_판결서/2 saved.
# 대전지법_2014나104405_판결서/3 saved.
# 대전지법_2014나104405_판결서/4 saved.
# 성남지원_2013가합658_판결서/0 saved.
# 성남지원_2013가합658_판결서/1 saved.
# 성남지원_2013가합658_판결서/2 saved.
# 성남지원_2013가합658_판결서/3 saved.
# 성남지원_2013가합658_판결서/4 saved.
# 성남지원_2013가합658_판결서/5 saved.
# 성남지원_2013가합658_판결서/6 saved.
# 성남지원_2013가합658_판결서/7 saved.
# 성남지원_2013가합658_판결서/8 saved.
# 성남지원_2013가합658_판결서/9 saved.
# 성남지원_2013가합658_판결서/10 saved.
# 성남지원_2013가합658_판결서/11 saved.
# 성남지원_2013가합658_판결서/12 saved.
# 성남지원_2013가합658_판결서/13 saved.
# 성남지원_2013가합658_판결서/14 saved.
# 성남지원_2013가합658_판결서/15 saved.
# 성남지원_2013가합658_판결서/16 saved.
# 성남지원_2013가합658_판결서/17 saved.
# 성남지원_2013가합658_판결서/18 saved.
# 성남지원_2013가합658_판결서/19 saved.
# 성남지원_2013가합658_판결서/20 saved.
# 성남지원_2013가합658_판결서/21 saved.
# 성남지원_2013가합658_판결서/22 saved.
# 성남지원_2013가합658_판결서/23 saved.
# 성남지원_2013가합658_판결서/24 saved.
# 성남지원_2013가합658_판결서/25 saved.
# 성남지원_2013가합658_판결서/26 saved.
# 성남지원_2013가합658_판결서/27 saved.
# 성남지원_2013가합658_판결서/28 saved.
# 성남지원_2013가합658_판결서/29 saved.
# 성남지원_2013가합658_판결서/30 saved.
# 성남지원_2013가합658_판결서/31 saved.
# 성남지원_2013가합658_판결서/32 saved.
# 성남지원_2013가합658_판결서/33 saved.
# 성남지원_2013가합658_판결서/34 saved.
# 성남지원_2013가합658_판결서/35 saved.
# 성남지원_2013가합658_판결서/36 saved.
# 성남지원_2013가합658_판결서/37 saved.
# 성남지원_2013가합658_판결서/38 saved.
# 성남지원_2013가합658_판결서/39 saved.
# 성남지원_2013가합658_판결서/40 saved.
# 성남지원_2013가합658_판결서/41 saved.
# 성남지원_2013가합658_판결서/42 saved.
# 성남지원_2013가합658_판결서/43 saved.
# 성남지원_2013가합658_판결서/44 saved.
# 성남지원_2013가합658_판결서/45 saved.
# 성남지원_2013가합658_판결서/46 saved.
# 성남지원_2013가합658_판결서/47 saved.
# 성남지원_2013가합658_판결서/48 saved.
# 성남지원_2013가합658_판결서/49 saved.
# 성남지원_2013가합658_판결서/50 saved.
# 성남지원_2013가합658_판결서/51 saved.
# 성남지원_2013가합658_판결서/52 saved.
# 성남지원_2013가합658_판결서/53 saved.
# 성남지원_2013가합658_판결서/54 saved.
# 성남지원_2013가합658_판결서/55 saved.
# 성남지원_2013가합658_판결서/56 saved.
# 성남지원_2013가합658_판결서/57 saved.
# 성남지원_2013가합658_판결서/58 saved.
# 성남지원_2013가합658_판결서/59 saved.
# 성남지원_2013가합658_판결서/60 saved.
# 대전지방법원 천안지원_2011가단22869_판결서/0 saved.
# 대전지방법원 천안지원_2011가단22869_판결서/1 saved.
# 대전지방법원 천안지원_2011가단22869_판결서/2 saved.
# 대전지방법원 천안지원_2011가단22869_판결서/3 saved.
# 서울서부지법_2014나33776_판결서/0 saved.
# 서울서부지법_2014나33776_판결서/1 saved.
# 서울서부지법_2014나33776_판결서/2 saved.
# 서울서부지법_2014나33776_판결서/3 saved.
# 서울서부지법_2014나33776_판결서/4 saved.
# 서울서부지법_2014나33776_판결서/5 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/0 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/1 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/2 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/3 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/4 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/5 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/6 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/7 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/8 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/9 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/10 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/11 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/12 saved.
# 서울중앙지법_2013가단201996 (1)_판결서/13 saved.
# 대전지방법원 공주지원_2013가합20065_별지4/0 saved.
# 대전지법_2014가단25075_판결서/0 saved.
# 대전지법_2014가단25075_판결서/1 saved.
# 대전지법_2014가단25075_판결서/2 saved.
# 대전지법_2014가단25075_판결서/3 saved.
# 대전지법_2014가단25075_판결서/4 saved.
# 대전지법_2014가단25075_판결서/5 saved.
# 대전지법_2014가단25075_판결서/6 saved.
# 대구지법_2014가단32813_판결서/0 saved.
# 대구지법_2014가단32813_판결서/1 saved.
# 대구지법_2014가단32813_판결서/2 saved.
# 대구지법_2014가단32813_판결서/3 saved.
# 대구지법_2014가단32813_판결서/4 saved.
# 대전지법_2014나8262_판결서/0 saved.
# 대전지법_2014나8262_판결서/1 saved.
# 대전지법_2014나8262_판결서/2 saved.
# 대전지법_2014나8262_판결서/3 saved.
# 대전지법_2014나8262_판결서/4 saved.
# 대전지법_2014나8262_판결서/5 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/0 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/1 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/2 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/3 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/4 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/5 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/6 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/7 saved.
# 인천지방법원 부천지원_2014가단46473_판결서/8 saved.
# 부산고법_2016재나19_판결서/0 saved.
# 부산고법_2016재나19_판결서/1 saved.
# 부산고법_2016재나19_판결서/2 saved.
# 서울중앙지법_2014나20263_판결서/0 saved.
# 서울중앙지법_2014나20263_판결서/1 saved.
# 서울중앙지법_2014나20263_판결서/2 saved.
# 서울중앙지법_2014나20263_판결서/3 saved.
# 서울중앙지법_2014나20263_판결서/4 saved.
# 서울중앙지법_2014나20263_판결서/5 saved.
# 대전지방법원 서산지원_2014가단11279_판결서/0 saved.
# 대전지방법원 서산지원_2014가단11279_판결서/1 saved.
# 대전지방법원 서산지원_2014가단11279_판결서/2 saved.
# 대전지방법원 서산지원_2014가단11279_판결서/3 saved.
# 대전지방법원 서산지원_2014가단11279_판결서/4 saved.
# 성남지원_2014가합6943_판결서/0 saved.
# 성남지원_2014가합6943_판결서/1 saved.
# 성남지원_2014가합6943_판결서/2 saved.
# 성남지원_2014가합6943_판결서/3 saved.
# 성남지원_2014가합6943_판결서/4 saved.
# 성남지원_2014가합6943_판결서/5 saved.
# 성남지원_2014가합6943_판결서/6 saved.
# 성남지원_2014가합6943_판결서/7 saved.
# 성남지원_2014가합6943_판결서/8 saved.
# 서울동부지법_2013가단119755_판결서/0 saved.
# 서울동부지법_2013가단119755_판결서/1 saved.
# 서울동부지법_2013가단119755_판결서/2 saved.
# 서울동부지법_2013가단119755_판결서/3 saved.
# 서울동부지법_2013가단119755_판결서/4 saved.
# 서울동부지법_2013가단119755_판결서/5 saved.
# 의정부지법_2014가단108072_판결서/0 saved.
# 의정부지법_2014가단108072_판결서/1 saved.
# 의정부지법_2014가단108072_판결서/2 saved.
# 의정부지법_2014가단108072_판결서/3 saved.
# 의정부지법_2014가단108072_판결서/4 saved.
# 청주지법_2014나384_판결서/0 saved.
# 청주지법_2014나384_판결서/1 saved.
# 청주지법_2014나384_판결서/2 saved.
# 청주지법_2014나384_판결서/3 saved.
# 청주지법_2014나384_판결서/4 saved.
# 청주지법_2014나384_판결서/5 saved.
# 청주지법_2014나384_판결서/6 saved.
# 청주지법_2014나384_판결서/7 saved.
# 청주지법_2014나384_판결서/8 saved.
# 청주지법_2014나384_판결서/9 saved.
# 청주지법_2014나384_판결서/10 saved.
# 청주지법_2014나384_판결서/11 saved.
# 청주지법_2014나384_판결서/12 saved.
# 청주지법_2014나384_판결서/13 saved.
# 청주지법_2014나384_판결서/14 saved.
# 청주지법_2014나384_판결서/15 saved.
# 청주지법_2014나384_판결서/16 saved.
# 청주지법_2014나384_판결서/17 saved.
# 서울행정법원_2015구합64565_판결서/0 saved.
# 서울행정법원_2015구합64565_판결서/1 saved.
# 서울행정법원_2015구합64565_판결서/2 saved.
# 서울행정법원_2015구합64565_판결서/3 saved.
# 서울행정법원_2015구합64565_판결서/4 saved.
# 서울행정법원_2015구합64565_판결서/5 saved.
# 서울행정법원_2015구합64565_판결서/6 saved.
# 서울행정법원_2015구합64565_판결서/7 saved.
# 서울행정법원_2015구합64565_판결서/8 saved.
# 서울행정법원_2015구합64565_판결서/9 saved.
# 서울중앙지법_2014가단5128369_판결서/0 saved.
# 서울중앙지법_2014가단5128369_판결서/1 saved.
# 서울중앙지법_2014가단5128369_판결서/2 saved.
# 서울중앙지법_2014가단5128369_판결서/3 saved.
# 서울중앙지법_2014가단5128369_판결서/4 saved.
# 서울중앙지법_2014가단5128369_판결서/5 saved.
# 광주지법_2014가단33517_판결서/0 saved.
# 광주지법_2014가단33517_판결서/1 saved.
# 광주지법_2014가단33517_판결서/2 saved.
# 광주지법_2014가단33517_판결서/3 saved.
# 광주지법_2014가단33517_판결서/4 saved.
# 광주지법_2014가단33517_판결서/5 saved.
# 수원지법_2013가단102431_판결서/0 saved.
# 수원지법_2013가단102431_판결서/1 saved.
# 수원지법_2013가단102431_판결서/2 saved.
# 수원지법_2013가단102431_판결서/3 saved.
# 수원지법_2013가단102431_판결서/4 saved.
# 수원지법_2013가단102431_판결서/5 saved.
# 서울행정법원_2016구단4884_판결서/0 saved.
# 서울행정법원_2016구단4884_판결서/1 saved.
# 서울행정법원_2016구단4884_판결서/2 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/0 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/1 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/2 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/3 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/4 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/5 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/6 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/7 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/8 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/9 saved.
# 인천지방법원 부천지원_2014가단7188_판결서/10 saved.
# 인천지법_2014가합10461_경정결정3/0 saved.
# 인천지법_2014가합10461_경정결정3/1 saved.
# 고양지원_2014가단61800_경정결정/0 saved.
# 대구고법_2014나22735_판결서/0 saved.
# 대구고법_2014나22735_판결서/1 saved.
# 대구고법_2014나22735_판결서/2 saved.
# 대구고법_2014나22735_판결서/3 saved.
# 대구고법_2014나22735_판결서/4 saved.
# 대구고법_2014나22735_판결서/5 saved.
# 청주지법_2013가단4944_판결서/0 saved.
# 청주지법_2013가단4944_판결서/1 saved.
# 청주지법_2013가단4944_판결서/2 saved.
# 청주지법_2013가단4944_판결서/3 saved.
# 청주지법_2013가단4944_판결서/4 saved.
# 청주지법_2013가단4944_판결서/5 saved.
# 청주지법_2013가단4944_판결서/6 saved.
# 청주지법_2013가단4944_판결서/7 saved.
# 청주지법_2013가단4944_판결서/8 saved.
# 청주지법_2013가단4944_판결서/9 saved.
# 청주지법_2013가단4944_판결서/10 saved.
# 대구지방법원 의성지원_2014가단3063_판결서/0 saved.
# 대구지방법원 의성지원_2014가단3063_판결서/1 saved.
# 대구지방법원 의성지원_2014가단3063_판결서/2 saved.
# 대구지방법원 의성지원_2014가단3063_판결서/3 saved.
# 대구지방법원 의성지원_2014가단3063_판결서/4 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/0 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/1 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/2 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/3 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/4 saved.
# 대구지방법원 김천지원_2014가단8567_판결서/5 saved.
# 대구지방법원 의성지원_2014가단2985_판결서/0 saved.
# 대구지방법원 의성지원_2014가단2985_판결서/1 saved.
# 대구지방법원 의성지원_2014가단2985_판결서/2 saved.
# 대구지방법원 의성지원_2014가단2985_판결서/3 saved.
# 평택지원_2015가단385_판결서/0 saved.
# 평택지원_2015가단385_판결서/1 saved.
# 평택지원_2015가단385_판결서/2 saved.
# 평택지원_2015가단385_판결서/3 saved.
# 서울남부지법_2013가합19527_판결서/0 saved.
# 서울남부지법_2013가합19527_판결서/1 saved.
# 서울남부지법_2013가합19527_판결서/2 saved.
# 서울남부지법_2013가합19527_판결서/3 saved.
# 서울남부지법_2013가합19527_판결서/4 saved.
# 서울남부지법_2013가합19527_판결서/5 saved.
# 서울남부지법_2013가합19527_판결서/6 saved.
# 서울남부지법_2013가합19527_판결서/7 saved.
# 서울남부지법_2013가합19527_판결서/8 saved.
# 서울남부지법_2013가합19527_판결서/9 saved.
# 서울남부지법_2013가합19527_판결서/10 saved.
# 서울남부지법_2013가합19527_판결서/11 saved.
# 서울남부지법_2013가합19527_판결서/12 saved.
# 서울남부지법_2013가합19527_판결서/13 saved.
# 서울남부지법_2013가합19527_판결서/14 saved.
# 서울남부지법_2013가합19527_판결서/15 saved.
# 서울남부지법_2013가합19527_판결서/16 saved.
# 서울남부지법_2013가합19527_판결서/17 saved.
# 서울남부지법_2013가합19527_판결서/18 saved.
# 안산지원_2013가단26999_판결서/0 saved.
# 안산지원_2013가단26999_판결서/1 saved.
# 안산지원_2013가단26999_판결서/2 saved.
# 안산지원_2013가단26999_판결서/3 saved.
# 안산지원_2013가단26999_판결서/4 saved.
# 성남지원_2012가합24350_판결서/0 saved.
# 성남지원_2012가합24350_판결서/1 saved.
# 성남지원_2012가합24350_판결서/2 saved.
# 성남지원_2012가합24350_판결서/3 saved.
# 대구지법_2014가단52008_판결서/0 saved.
# 대구지법_2014가단52008_판결서/1 saved.
# 대구지법_2014가단52008_판결서/2 saved.
# 서울중앙지법_2014가합556225_판결서/0 saved.
# 서울중앙지법_2014가합556225_판결서/1 saved.
# 서울중앙지법_2014가합556225_판결서/2 saved.
# 서울중앙지법_2014가합556225_판결서/3 saved.
# 서울중앙지법_2014가합556225_판결서/4 saved.
# 서울중앙지법_2014가합556225_판결서/5 saved.
# 서울중앙지법_2014가합556225_판결서/6 saved.
# 서울중앙지법_2014가합556225_판결서/7 saved.
# 속초지원_2015가단429_판결서/0 saved.
# 속초지원_2015가단429_판결서/1 saved.
# 속초지원_2015가단429_판결서/2 saved.
# 서울남부지법_2014가단55318_판결서/0 saved.
# 서울남부지법_2014가단55318_판결서/1 saved.
# 서울남부지법_2014가단55318_판결서/2 saved.
# 서울남부지법_2014가단55318_판결서/3 saved.
# 서울남부지법_2014가단55318_판결서/4 saved.
# 수원지법_2013구합11506_판결서/0 saved.
# 수원지법_2013구합11506_판결서/1 saved.
# 수원지법_2013구합11506_판결서/2 saved.
# 수원지법_2013구합11506_판결서/3 saved.
# 수원지법_2013구합11506_판결서/4 saved.
# 수원지법_2013구합11506_판결서/5 saved.
# 수원지법_2013구합11506_판결서/6 saved.
# 수원지법_2013구합11506_판결서/7 saved.
# 수원지법_2013구합11506_판결서/8 saved.
# 부산지법_2013가합12429_판결서/0 saved.
# 부산지법_2013가합12429_판결서/1 saved.
# 부산지법_2013가합12429_판결서/2 saved.
# 부산지법_2013가합12429_판결서/3 saved.
# 부산지법_2013가합12429_판결서/4 saved.
# 부산지법_2013가합12429_판결서/5 saved.
# 부산지법_2013가합12429_판결서/6 saved.
# 부산지법_2013가합12429_판결서/7 saved.
# 부산지법_2013가합12429_판결서/8 saved.
# 부산지법_2013가합12429_판결서/9 saved.
# 부산지법_2013가합12429_판결서/10 saved.
# 부산지법_2013가합12429_판결서/11 saved.
# 부산지법_2013가합12429_판결서/12 saved.
# 부산지법_2013가합12429_판결서/13 saved.
# 부산지법_2013가합12429_판결서/14 saved.
# 부산지법_2013가합12429_판결서/15 saved.
# 서울서부지법_2014가단226294_판결서/0 saved.
# 서울서부지법_2014가단226294_판결서/1 saved.
# 서울서부지법_2014가단226294_판결서/2 saved.
# 서울서부지법_2014가단226294_판결서/3 saved.
# 강릉지원_2014가단6318_판결서/0 saved.
# 강릉지원_2014가단6318_판결서/1 saved.
# 강릉지원_2014가단6318_판결서/2 saved.
# 강릉지원_2014가단6318_판결서/3 saved.
# 강릉지원_2014가단6318_판결서/4 saved.
# 강릉지원_2014가단6318_판결서/5 saved.
# 서울중앙지법_2014가단215053_판결서/0 saved.
# 서울중앙지법_2014가단215053_판결서/1 saved.
# 서울중앙지법_2014가단215053_판결서/2 saved.
# 대구지법_2012가합43687_판결서/0 saved.
# 대구지법_2012가합43687_판결서/1 saved.
# 대구지법_2012가합43687_판결서/2 saved.
# 대구지법_2012가합43687_판결서/3 saved.
# 대구지법_2012가합43687_판결서/4 saved.
# 대구지법_2012가합43687_판결서/5 saved.
# 대구지법_2012가합43687_판결서/6 saved.
# 대구지법_2012가합43687_판결서/7 saved.
# 대구지법_2012가합43687_판결서/8 saved.
# 대구지법_2012가합43687_판결서/9 saved.
# 대구지법_2012가합43687_판결서/10 saved.
# 대구지법_2012가합43687_판결서/11 saved.
# 대구지법_2012가합43687_판결서/12 saved.
# 대구지법_2012가합43687_판결서/13 saved.
# 대구지법_2012가합43687_판결서/14 saved.
# 대구지법_2012가합43687_판결서/15 saved.
# 대구지법_2012가합43687_판결서/16 saved.
# 대구지법_2012가합43687_판결서/17 saved.
# 대구지법_2012가합43687_판결서/18 saved.
# 대구지법_2012가합43687_판결서/19 saved.
# 대구지법_2012가합43687_판결서/20 saved.
# 대구지법_2012가합43687_판결서/21 saved.
# 대구지법_2012가합43687_판결서/22 saved.
# 대구지법_2012가합43687_판결서/23 saved.
# 대구지법_2012가합43687_판결서/24 saved.
# 대구지법_2012가합43687_판결서/25 saved.
# 대구지법_2012가합43687_판결서/26 saved.
# 대구지법_2012가합43687_판결서/27 saved.
# 대구지법_2012가합43687_판결서/28 saved.
# 대구지법_2012가합43687_판결서/29 saved.
# 대구지법_2012가합43687_판결서/30 saved.
# 대구지법_2012가합43687_판결서/31 saved.
# 대구지법_2012가합43687_판결서/32 saved.
# 대구지법_2012가합43687_판결서/33 saved.
# 대구지법_2012가합43687_판결서/34 saved.
# 대구지법_2012가합43687_판결서/35 saved.
# 대구지법_2012가합43687_판결서/36 saved.
# 대구지법_2012가합43687_판결서/37 saved.
# 대구지법_2012가합43687_판결서/38 saved.
# 대구지법_2012가합43687_판결서/39 saved.
# 대구지법_2012가합43687_판결서/40 saved.
# 대구지법_2012가합43687_판결서/41 saved.
# 대구지법_2012가합43687_판결서/42 saved.
# 대구지법_2012가합43687_판결서/43 saved.
# 대구지법_2012가합43687_판결서/44 saved.
# 대구지법_2012가합43687_판결서/45 saved.
# 대구지법_2012가합43687_판결서/46 saved.
# 대구지법_2012가합43687_판결서/47 saved.
# 대구지법_2012가합43687_판결서/48 saved.
# 서울서부지법_2014가단13665_판결서/0 saved.
# 서울서부지법_2014가단13665_판결서/1 saved.
# 서울서부지법_2014가단13665_판결서/2 saved.
# 서울서부지법_2014가단13665_판결서/3 saved.
# 서울고법_2012나45797_판결서/0 saved.
# 서울고법_2012나45797_판결서/1 saved.
# 서울고법_2012나45797_판결서/2 saved.
# 서울고법_2012나45797_판결서/3 saved.
# 서울고법_2012나45797_판결서/4 saved.
# 서울고법_2012나45797_판결서/5 saved.
# 서울고법_2012나45797_판결서/6 saved.
# 서울고법_2012나45797_판결서/7 saved.
# 서울고법_2012나45797_판결서/8 saved.
# 서울고법_2012나45797_판결서/9 saved.
# 서울고법_2012나45797_판결서/10 saved.
# 서울고법_2012나45797_판결서/11 saved.
# 서울고법_2012나45797_판결서/12 saved.
# 서울고법_2012나45797_판결서/13 saved.
# 서울고법_2014나2028952_판결서/0 saved.
# 서울고법_2014나2028952_판결서/1 saved.
# 서울고법_2014나2028952_판결서/2 saved.
# 서울고법_2014나2028952_판결서/3 saved.
# 서울고법_2014나2028952_판결서/4 saved.
# 서울고법_2014나2028952_판결서/5 saved.
# 서울고법_2014나2028952_판결서/6 saved.
# 서울고법_2014나2028952_판결서/7 saved.
# 서울고법_2014나2028952_판결서/8 saved.
# 서울고법_2014나2028952_판결서/9 saved.
# 서울고법_2014나2028952_판결서/10 saved.
# 서울고법_2014나2028952_판결서/11 saved.
# 서울고법_2014나2028952_판결서/12 saved.
# 서울고법_2014나2028952_판결서/13 saved.
# 서울고법_2014나2028952_판결서/14 saved.
# 서울고법_2014나2028952_판결서/15 saved.
# 수원지법_2014가단74847_판결서/0 saved.
# 수원지법_2014가단74847_판결서/1 saved.
# 수원지법_2014가단74847_판결서/2 saved.
# 진주지원_2014가단10164_판결서/0 saved.
# 진주지원_2014가단10164_판결서/1 saved.
# 진주지원_2014가단10164_판결서/2 saved.
# 진주지원_2014가단10164_판결서/3 saved.
# 부산지법_2013가합17837_판결서/0 saved.
# 부산지법_2013가합17837_판결서/1 saved.
# 부산지법_2013가합17837_판결서/2 saved.
# 부산지법_2013가합17837_판결서/3 saved.
# 부산지법_2013가합17837_판결서/4 saved.
# 부산지법_2013가합17837_판결서/5 saved.
# 부산지법_2013가합17837_판결서/6 saved.
# 부산지법_2013가합17837_판결서/7 saved.
# 부산지법_2013가합17837_판결서/8 saved.
# 부산지법_2013가합17837_판결서/9 saved.
# 부산지법_2013가합17837_판결서/10 saved.
# 부산지법_2013가합17837_판결서/11 saved.
# 부산지법_2013가합17837_판결서/12 saved.
# 부산지법_2013가합17837_판결서/13 saved.
# 부산지법_2013가합17837_판결서/14 saved.
# 부산지법_2013가합17837_판결서/15 saved.
# 서울중앙지법_2016가단682_판결서/0 saved.
# 서울중앙지법_2016가단682_판결서/1 saved.
# 서울중앙지법_2014가단224460_판결서/0 saved.
# 서울중앙지법_2014가단224460_판결서/1 saved.
# 서울중앙지법_2014가단224460_판결서/2 saved.
# 대전지법_2014나11411_판결서/0 saved.
# 대전지법_2014나11411_판결서/1 saved.
# 대전지법_2014나11411_판결서/2 saved.
# 대전지법_2014나11411_판결서/3 saved.
# 대전지법_2014나11411_판결서/4 saved.
# 대전지법_2014나11411_판결서/5 saved.
# 서울고법_2013나48342_판결서/0 saved.
# 서울고법_2013나48342_판결서/1 saved.
# 서울고법_2013나48342_판결서/2 saved.
# 서울고법_2013나48342_판결서/3 saved.
# 서울고법_2013나48342_판결서/4 saved.
# 서울고법_2013나48342_판결서/5 saved.
# 서울고법_2013나48342_판결서/6 saved.
# 서울고법_2013나48342_판결서/7 saved.
# 서울고법_2013나48342_판결서/8 saved.
# 서울고법_2013나48342_판결서/9 saved.
# 서울고법_2013나48342_판결서/10 saved.
# 서울중앙지법_2014가단48666_판결서/0 saved.
# 서울중앙지법_2014가단48666_판결서/1 saved.
# 서울중앙지법_2014가단48666_판결서/2 saved.
# 서울중앙지법_2014가단48666_판결서/3 saved.
# 서울중앙지법_2014가단48666_판결서/4 saved.
# 서울고법_2014나2047991_판결서/0 saved.
# 서울고법_2014나2047991_판결서/1 saved.
# 서울고법_2014나2047991_판결서/2 saved.
# 서울고법_2014나2047991_판결서/3 saved.
# 서울고법_2014나2047991_판결서/4 saved.
# 서울고법_2014나2047991_판결서/5 saved.
# 서울고법_2014나2047991_판결서/6 saved.
# 서울고법_2014나2047991_판결서/7 saved.
# 서울고법_2014나2047991_판결서/8 saved.
# 서울남부지법_2013가단83163_판결서/0 saved.
# 서울남부지법_2013가단83163_판결서/1 saved.
# 서울남부지법_2013가단83163_판결서/2 saved.
# 서울남부지법_2013가단83163_판결서/3 saved.
# 인천지법_2014가합55044_판결서/0 saved.
# 인천지법_2014가합55044_판결서/1 saved.
# 인천지법_2014가합55044_판결서/2 saved.
# 인천지법_2014가합55044_판결서/3 saved.
# 인천지법_2014가합55044_판결서/4 saved.
# 인천지법_2014가합55044_판결서/5 saved.
# 서울중앙지법_2014가단5258451_판결서/0 saved.
# 서울중앙지법_2014가단5258451_판결서/1 saved.
# 서울중앙지법_2014가단5258451_판결서/2 saved.
# 서울중앙지법_2014가단5258451_판결서/3 saved.
# 서울중앙지법_2014가단5258451_판결서/4 saved.
# 대구지법서부지원_2014가단28729_판결서/0 saved.
# 대구지법서부지원_2014가단28729_판결서/1 saved.
# 대구지법서부지원_2014가단28729_판결서/2 saved.
# 대구지법서부지원_2014가단28729_판결서/3 saved.
# 대구지법서부지원_2014가단28729_판결서/4 saved.
# 전주지법_2015가단405_판결서/0 saved.
# 전주지법_2015가단405_판결서/1 saved.
# 전주지법_2015가단405_판결서/2 saved.
# 전주지법_2015가단405_판결서/3 saved.
# 전주지법_2015가단405_판결서/4 saved.
# 서울중앙지법_2016가단5012574_판결서/0 saved.
# 서울중앙지법_2016가단5012574_판결서/1 saved.
# 서울중앙지법_2016가단5012574_판결서/2 saved.

# %% [markdown]
# ### in subfolders

# %%
pdf_folder = './testdata/PDFs_original'
output_folder = './testdata/CONVERTED_JPEG'

convert_pdf_to_images(pdf_folder, output_folder)
